# %% [markdown]
# ### Data Analysis Pipeline
#
# - **Create Simulation**: Represent recent and moderate selection.
# - **Leverage Pre-trained Model**: Use the hyperpamaters from bayesian optimisation
# - **Training Regimen**:
#   - Train for 10 epochs.
#   - 10 epochs each from batches 1-9 of training data.
#   - Test on the final batch of unseen data.
# - **40k Simulations used**

# %%
import os
import gzip
import _pickle as pickle

import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models, layers, activations, optimizers, regularizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix

import itertools
import matplotlib.pyplot as plt
import skimage.transform
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense,Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")


# Set a fixed random seed for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Run ImaGene.py

# %%
# %run -i ../../ImaGene.py

# %% [markdown]
#  the first iteration of training.

# %%
path_sim = './'

# %%
file_sim = ImaFile(simulations_folder=path_sim + 'RM/Simulations1', nr_samples=198, model_name='Marth-3epoch-CEU');

# %% [markdown]
# Then, we populate an _ImaGene_ object by specifying the variable we want to estimate/predict (`selection_coeff_hetero`) and how many data points per class we wish to retain.
# As a quick example, we will use only 2000 data points per class.

# %%
gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000);

# %% [markdown]
# We can have a look at the data stored in this object.

# %%
gene_sim.summary();
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 203, max 493, mean 341.473250, std 35.400597

# %%
# Filter simulations based on frequency threshold of 0.01
gene_sim.filter_freq(0.01)

# Sort simulations by row frequency
gene_sim.sort('rows_freq')

# Provide summary of the simulation data
gene_sim.summary()
# Resize simulation data to (198, 192)
gene_sim.resize((198, 192))

# Provide summary of the simulation data
gene_sim.summary()
# Convert simulation data with data augmentation (flip)
gene_sim.convert(flip=True)

# Provide summary of the simulation data
gene_sim.summary()
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 117, max 398, mean 254.190500, std 33.206162
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# 0

# %% [markdown]
# information on the corresponding targets (in this case the selection coefficient, either 0 or selection coefficient of choice in $2N_e$ units with $N_e = 10000$).

# %%
for sel in gene_sim.classes:
    print(sel)
    gene_sim.plot(np.where(gene_sim.targets == sel)[0][0])
# Out:
# 0
# 200

# %%
# Subset the simulation data with random indices
gene_sim.subset(get_index_random(gene_sim))

# Convert targets to binary format
gene_sim.targets = to_binary(gene_sim.targets)

# %% [markdown]
# Use Hyperparameters from the Bayesian Optimisation script

# %%
def build_best_model(input_shape):
    # Best hyperparameters from Optuna optimization
    num_layers = 5
    filters = [85, 119, 99, 115, 54]
    kernel_size = 3
    l1 = 0.00020959985382232806
    l2 = 0.00010741242396156945
    dense_units = 69
    dropout_rate = 0.29601406545155096
    learning_rate = 0.00013314057394016722

    # Building the model based on the best hyperparameters
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))  # Define the input layer
    for i in range(num_layers):
        model.add(layers.Conv2D(filters=filters[i], kernel_size=(kernel_size, kernel_size), strides=(1, 1), activation='relu',
                                kernel_regularizer=regularizers.l1_l2(l1=l1, l2=l2), padding='same'))  # Use 'same' padding to avoid dimension issues
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Flatten())  # Flatten the output for the Dense layers
    model.add(layers.Dense(units=dense_units, activation='relu'))  # Add Dense layer
    model.add(layers.Dropout(rate=dropout_rate))  # Add Dropout layer
    model.add(layers.Dense(units=1, activation='sigmoid'))  # Output layer with sigmoid activation

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Define optimizer
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])  # Compile the model

    return model

# gene_sim.data is already preprocessed
input_shape = gene_sim.data.shape[1:]

# Build the model
model = build_best_model(input_shape)

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 192, 85)        │             850 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 99, 96, 85)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 99, 96, 119)         │          91,154 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 49, 48, 119)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 49, 48, 99)          │         106,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 99)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 115)         │         102,580 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 115)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 12, 12, 54)          │          55,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 6, 6, 54)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1944)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 69)                  │         134,205 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 69)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              70 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 490,931 (1.87 MB)
#  Trainable params: 490,931 (1.87 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.4955 - loss: 2.7734 - val_accuracy: 0.5300 - val_loss: 2.4886
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5150 - loss: 2.3986 - val_accuracy: 0.5175 - val_loss: 2.1346
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5189 - loss: 2.0534 - val_accuracy: 0.7900 - val_loss: 1.8176
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5675 - loss: 1.7455 - val_accuracy: 0.7425 - val_loss: 1.5392
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5894 - loss: 1.4749 - val_accuracy: 0.7713 - val_loss: 1.2423
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.7170 - loss: 1.1543 - val_accuracy: 0.8100 - val_loss: 0.8900
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.7935 - loss: 0.9072 - val_accuracy: 0.8375 - val_loss: 0.7501
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.7750 - loss: 0.7929 - val_accuracy: 0.8400 - val_loss: 0.6691
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.7989 - loss: 0.7112 - val_accuracy: 0.8425 - val_loss: 0.6232
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8044 - loss: 0.6599 - val_accuracy: 0.8388 - val_loss: 0.5998

# %%
net_LCT = ImaNet(name='Bayesian_opt_ARC')

# %%
net_LCT.update_scores(score);

# %%
i = 2
all_scores = {
    'loss': [],
    'val_loss': [],
    'accuracy': [],
    'val_accuracy': []
}

i = 2
while i < 10:

    print(i)

    file_sim = ImaFile(simulations_folder=path_sim + 'RM/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')
    gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

    gene_sim.filter_freq(0.01)
    gene_sim.sort('rows_freq')
    gene_sim.resize((198, 192))
    gene_sim.convert(flip=True)

    gene_sim.subset(get_index_random(gene_sim))
    gene_sim.targets = to_binary(gene_sim.targets)

    score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)

    # Append scores to all_scores dictionary
    all_scores['loss'].extend(score.history['loss'])
    all_scores['val_loss'].extend(score.history['val_loss'])
    all_scores['accuracy'].extend(score.history['accuracy'])
    all_scores['val_accuracy'].extend(score.history['val_accuracy'])

    i += 1
# Out:
# 2
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.7993 - loss: 0.6733 - val_accuracy: 0.8300 - val_loss: 0.6037
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.7962 - loss: 0.6412 - val_accuracy: 0.8300 - val_loss: 0.5850
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8140 - loss: 0.6148 - val_accuracy: 0.8213 - val_loss: 0.5717
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8112 - loss: 0.6025 - val_accuracy: 0.8263 - val_loss: 0.5740
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8042 - loss: 0.6049 - val_accuracy: 0.8363 - val_loss: 0.5484
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8176 - loss: 0.5836 - val_accuracy: 0.8350 - val_loss: 0.5427
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8125 - loss: 0.5726 - val_accuracy: 0.8363 - val_loss: 0.5349
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8164 - loss: 0.5686 - val_accuracy: 0.8338 - val_loss: 0.5311
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8145 - loss: 0.5622 - val_accuracy: 0.8300 - val_loss: 0.5289
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8176 - loss: 0.5559 - val_accuracy: 0.8375 - val_loss: 0.5233
# 3
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8339 - loss: 0.5079 - val_accuracy: 0.8350 - val_loss: 0.5370
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8308 - loss: 0.5132 - val_accuracy: 0.8087 - val_loss: 0.5519
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8343 - loss: 0.5081 - val_accuracy: 0.8325 - val_loss: 0.5307
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8388 - loss: 0.4994 - val_accuracy: 0.8425 - val_loss: 0.5208
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8342 - loss: 0.4944 - val_accuracy: 0.8275 - val_loss: 0.5272
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8401 - loss: 0.4897 - val_accuracy: 0.8250 - val_loss: 0.5231
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8365 - loss: 0.4906 - val_accuracy: 0.8350 - val_loss: 0.5124
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8385 - loss: 0.4888 - val_accuracy: 0.8388 - val_loss: 0.5106
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8349 - loss: 0.4839 - val_accuracy: 0.8288 - val_loss: 0.5171
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8400 - loss: 0.4782 - val_accuracy: 0.8325 - val_loss: 0.5041
# 4
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8137 - loss: 0.5043 - val_accuracy: 0.8450 - val_loss: 0.4565
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8191 - loss: 0.4934 - val_accuracy: 0.8425 - val_loss: 0.4534
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8219 - loss: 0.4886 - val_accuracy: 0.8462 - val_loss: 0.4517
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8224 - loss: 0.4808 - val_accuracy: 0.8450 - val_loss: 0.4486
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8253 - loss: 0.4791 - val_accuracy: 0.8462 - val_loss: 0.4464
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8244 - loss: 0.4710 - val_accuracy: 0.8462 - val_loss: 0.4446
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8316 - loss: 0.4785 - val_accuracy: 0.8487 - val_loss: 0.4432
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8292 - loss: 0.4716 - val_accuracy: 0.8475 - val_loss: 0.4428
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8276 - loss: 0.4752 - val_accuracy: 0.8475 - val_loss: 0.4414
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8284 - loss: 0.4702 - val_accuracy: 0.8462 - val_loss: 0.4392
# 5
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8421 - loss: 0.4474 - val_accuracy: 0.8275 - val_loss: 0.4742
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8473 - loss: 0.4516 - val_accuracy: 0.8238 - val_loss: 0.4717
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8486 - loss: 0.4485 - val_accuracy: 0.8250 - val_loss: 0.4701
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8455 - loss: 0.4436 - val_accuracy: 0.8250 - val_loss: 0.4721
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8451 - loss: 0.4432 - val_accuracy: 0.8288 - val_loss: 0.4728
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8484 - loss: 0.4415 - val_accuracy: 0.8300 - val_loss: 0.4679
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8496 - loss: 0.4364 - val_accuracy: 0.8288 - val_loss: 0.4670
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8482 - loss: 0.4335 - val_accuracy: 0.8275 - val_loss: 0.4656
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8472 - loss: 0.4359 - val_accuracy: 0.8300 - val_loss: 0.4662
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8489 - loss: 0.4305 - val_accuracy: 0.8275 - val_loss: 0.4621
# 6
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8365 - loss: 0.4492 - val_accuracy: 0.8263 - val_loss: 0.4551
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8367 - loss: 0.4533 - val_accuracy: 0.8325 - val_loss: 0.4492
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8414 - loss: 0.4482 - val_accuracy: 0.8300 - val_loss: 0.4509
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8379 - loss: 0.4520 - val_accuracy: 0.8313 - val_loss: 0.4460
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8415 - loss: 0.4481 - val_accuracy: 0.8388 - val_loss: 0.4443
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8382 - loss: 0.4414 - val_accuracy: 0.8275 - val_loss: 0.4457
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8450 - loss: 0.4398 - val_accuracy: 0.8250 - val_loss: 0.4483
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8449 - loss: 0.4443 - val_accuracy: 0.8375 - val_loss: 0.4402
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8478 - loss: 0.4380 - val_accuracy: 0.8413 - val_loss: 0.4387
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8491 - loss: 0.4366 - val_accuracy: 0.8413 - val_loss: 0.4392
# 7
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8408 - loss: 0.4352 - val_accuracy: 0.8225 - val_loss: 0.4665
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8377 - loss: 0.4362 - val_accuracy: 0.8125 - val_loss: 0.4748
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8417 - loss: 0.4314 - val_accuracy: 0.8188 - val_loss: 0.4650
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8424 - loss: 0.4345 - val_accuracy: 0.8175 - val_loss: 0.4704
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8458 - loss: 0.4344 - val_accuracy: 0.8238 - val_loss: 0.4625
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8452 - loss: 0.4270 - val_accuracy: 0.8238 - val_loss: 0.4621
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8436 - loss: 0.4229 - val_accuracy: 0.8188 - val_loss: 0.4612
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8415 - loss: 0.4195 - val_accuracy: 0.8213 - val_loss: 0.4642
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8391 - loss: 0.4216 - val_accuracy: 0.8225 - val_loss: 0.4623
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8429 - loss: 0.4242 - val_accuracy: 0.8225 - val_loss: 0.4583
# 8
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8493 - loss: 0.4239 - val_accuracy: 0.8438 - val_loss: 0.4139
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8501 - loss: 0.4241 - val_accuracy: 0.8400 - val_loss: 0.4137
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8484 - loss: 0.4308 - val_accuracy: 0.8375 - val_loss: 0.4136
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8537 - loss: 0.4249 - val_accuracy: 0.8425 - val_loss: 0.4108
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8565 - loss: 0.4232 - val_accuracy: 0.8375 - val_loss: 0.4146
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8491 - loss: 0.4270 - val_accuracy: 0.8425 - val_loss: 0.4095
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8446 - loss: 0.4156 - val_accuracy: 0.8400 - val_loss: 0.4090
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8546 - loss: 0.4197 - val_accuracy: 0.8438 - val_loss: 0.4105
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8520 - loss: 0.4165 - val_accuracy: 0.8400 - val_loss: 0.4068
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8483 - loss: 0.4139 - val_accuracy: 0.8400 - val_loss: 0.4067
# 9
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.8449 - loss: 0.4323 - val_accuracy: 0.8363 - val_loss: 0.4229
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8415 - loss: 0.4354 - val_accuracy: 0.8338 - val_loss: 0.4237
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8446 - loss: 0.4352 - val_accuracy: 0.8313 - val_loss: 0.4205
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8388 - loss: 0.4268 - val_accuracy: 0.8275 - val_loss: 0.4198
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8427 - loss: 0.4322 - val_accuracy: 0.8300 - val_loss: 0.4205
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8425 - loss: 0.4250 - val_accuracy: 0.8313 - val_loss: 0.4196
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8408 - loss: 0.4216 - val_accuracy: 0.8300 - val_loss: 0.4184
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8422 - loss: 0.4256 - val_accuracy: 0.8275 - val_loss: 0.4183
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8432 - loss: 0.4228 - val_accuracy: 0.8313 - val_loss: 0.4188
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.8479 - loss: 0.4226 - val_accuracy: 0.8300 - val_loss: 0.4174

# %% [markdown]
# Better Plotting visualisation

# %%
# Define the number of epochs for plotting
epochs = range(1, len(all_scores['loss']) + 1)

# Function to smooth the data for better visualization (optional)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Create a figure for plotting with better visualization settings
plt.figure(figsize=(14, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, smooth_curve(all_scores['loss']), 'bo-', label='Training Loss')
plt.plot(epochs, smooth_curve(all_scores['val_loss']), 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, smooth_curve(all_scores['accuracy']), 'bo-', label='Training Accuracy')
plt.plot(epochs, smooth_curve(all_scores['val_accuracy']), 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluate the training on the testing dataset, Which is the last batch of the the 10th simulation in the file
# The log the testing validation and loss alongside the F1,

# %%
# Set the simulation index
i = 10

# Create an ImaFile object for the specified simulation folder and model
file_sim = ImaFile(simulations_folder=path_sim + 'RM/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')

# Read the simulation data with the specified parameter and maximum number of replicates
gene_sim_test = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

# Filter the simulations based on a frequency threshold of 0.01
gene_sim_test.filter_freq(0.01)

# Sort the simulations by row frequency
gene_sim_test.sort('rows_freq')

# Resize the simulation data to the specified dimensions (198, 192)
gene_sim_test.resize((198, 192))

# Convert the simulation data with data augmentation (flip=True)
gene_sim_test.convert(flip=True)

# Get a random subset of indices and subset the simulation data
rnd_idx = get_index_random(gene_sim_test)  # no need to create this extra variable
gene_sim_test.subset(rnd_idx)

# Convert the targets to binary format
gene_sim_test.targets = to_binary(gene_sim_test.targets)

# %%
net_LCT.test = model.evaluate(gene_sim_test.data, gene_sim_test.targets, batch_size=None, verbose=0)
print(net_LCT.test) # it will report [loss, accuracy]
# Out:
# [0.4077603220939636, 0.8454999923706055]

# %%
# Make predictions on the validation data
predictions = model.predict(gene_sim_test.data)

# Calculate F1 score
f1 = f1_score(gene_sim_test.targets, predictions.round())

# Calculate precision, recall, and F-score
precision, recall, fscore, _ = precision_recall_fscore_support(gene_sim_test.targets, predictions.round(), average='binary')

# Recall is equivalent to sensitivity
sensitivity = recall

# Compute ROC curve and AUC (Area Under the Curve)
fpr, tpr, _ = roc_curve(gene_sim_test.targets, predictions)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Print additional metrics
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall (Sensitivity): {sensitivity}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# F1 Score: 0.8365943945002644
# Precision: 0.8877665544332211
# Recall (Sensitivity): 0.791

# %%
# Make predictions on the test data using the trained model and store the results in net_LCT
net_LCT.predict(gene_sim_test, model)

# Plot the confusion matrix of the predictions against the true classes, with text labels for clarity
net_LCT.plot_cm(gene_sim_test.classes, text=True)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# 0

# %%
path = './'
filename = 'RM_Bayes_opt.keras'

# Save the trained model to a file using the recommended Keras format
model.save(path + filename)
#Model saved to Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the path and filename
path = '/content/drive/My Drive/models/'
filename = 'RM_Bayes_opt.keras'

# Save the trained model to the specified path
model.save(path + filename)
# Out:
# Mounted at /content/drive
