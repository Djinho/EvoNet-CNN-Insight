# %% [markdown]
# ### Data Analysis Pipeline
#
# - **Create Simulation**: Represent Ancient and strong selection.
# - **Leverage Pre-trained Model**: Use the hyperpamaters from bayesian optimisation
# - **Training Regimen**:
#   - Train for 10 epochs.
#   - 10 epochs each from batches 1-9 of training data.
#   - Test on the final batch of unseen data.
# - **40k Simulations used**

# %%
# !git clone https://github.com/Djinho/EvoNet-CNN-Insight.git

# Navigate to the cloned repository
# %cd EvoNet-CNN-Insight/model_training/Ancient_strong
# Out:
# Cloning into 'EvoNet-CNN-Insight'...
# remote: Enumerating objects: 5901, done.
# remote: Counting objects: 100% (1522/1522), done.
# remote: Compressing objects: 100% (1039/1039), done.
# remote: Total 5901 (delta 623), reused 1304 (delta 466), pack-reused 4379
# Receiving objects: 100% (5901/5901), 8.07 GiB | 17.13 MiB/s, done.
# Resolving deltas: 100% (2214/2214), done.
# Updating files: 100% (229/229), done.
# /content/EvoNet-CNN-Insight/model_training/Ancient_strong

# %%
import os
import gzip
import _pickle as pickle

import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models, layers, activations, optimizers, regularizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix

import itertools
import matplotlib.pyplot as plt
import skimage.transform
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense,Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")


# Set a fixed random seed for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Run ImaGene.py

# %%
# %run -i ../../ImaGene.py

# %%
#run to make simulations
import subprocess
subprocess.call("bash ../../generate_dataset.sh params_ancient_strong.txt".split());

# %% [markdown]
#  the first iteration of training.

# %%
path_sim = './'

# %%
file_sim = ImaFile(simulations_folder=path_sim + 'AS/Simulations1', nr_samples=198, model_name='Marth-3epoch-CEU');

# %% [markdown]
# Then, we populate an _ImaGene_ object by specifying the variable we want to estimate/predict (`selection_coeff_hetero`) and how many data points per class we wish to retain.
# As a quick example, we will use only 2000 data points per class.

# %%
gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000);

# %% [markdown]
# We can have a look at the data stored in this object.

# %%
gene_sim.summary();
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 186, max 508, mean 327.057250, std 41.736866

# %%
# Filter simulations based on frequency threshold of 0.01
gene_sim.filter_freq(0.01)

# Sort simulations by row frequency
gene_sim.sort('rows_freq')

# Provide summary of the simulation data
gene_sim.summary()
# Resize simulation data to (198, 192)
gene_sim.resize((198, 192))

# Provide summary of the simulation data
gene_sim.summary()
# Convert simulation data with data augmentation (flip)
gene_sim.convert(flip=True)

# Provide summary of the simulation data
gene_sim.summary()
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 111, max 397, mean 239.376750, std 39.731415
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# 0

# %% [markdown]
# information on the corresponding targets (in this case the selection coefficient, either 0 or selection coefficient of choice in $2N_e$ units with $N_e = 10000$).

# %%
for sel in gene_sim.classes:
    print(sel)
    gene_sim.plot(np.where(gene_sim.targets == sel)[0][0])
# Out:
# 0
# 300

# %%
# Subset the simulation data with random indices
gene_sim.subset(get_index_random(gene_sim))

# Convert targets to binary format
gene_sim.targets = to_binary(gene_sim.targets)

# %% [markdown]
# Use Hyperparameters from the Bayesian Optimisation script

# %%
def build_best_model(input_shape):
    # Best hyperparameters from Optuna optimization
    num_layers = 4
    filters = [88, 38, 88, 106]
    kernel_size = 3
    l1 = 1.5022150089120748e-05
    l2 = 0.0035801025371631446
    dense_units = 193
    dropout_rate = 0.2866844238417743
    learning_rate = 0.00016920857191232494

    # Building the model based on the best hyperparameters
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))  # Define the input layer
    for i in range(num_layers):
        model.add(layers.Conv2D(filters=filters[i], kernel_size=(kernel_size, kernel_size), strides=(1, 1), activation='relu',
                                kernel_regularizer=regularizers.l1_l2(l1=l1, l2=l2), padding='same'))  # Use 'same' padding to avoid dimension issues
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Flatten())  # Flatten the output for the Dense layers
    model.add(layers.Dense(units=dense_units, activation='relu'))  # Add Dense layer
    model.add(layers.Dropout(rate=dropout_rate))  # Add Dropout layer
    model.add(layers.Dense(units=1, activation='sigmoid'))  # Output layer with sigmoid activation

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Define optimizer
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])  # Compile the model

    return model

# Assuming gene_sim.data is already preprocessed
input_shape = gene_sim.data.shape[1:]

# Build the model
model = build_best_model(input_shape)

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 192, 88)        │             880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 99, 96, 88)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 99, 96, 38)          │          30,134 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 49, 48, 38)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 49, 48, 88)          │          30,184 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 88)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 106)         │          84,058 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 106)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 15264)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 193)                 │       2,946,145 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 193)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             194 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,091,595 (11.79 MB)
#  Trainable params: 3,091,595 (11.79 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.5101 - loss: 1.4390 - val_accuracy: 0.4825 - val_loss: 1.2797
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.5158 - loss: 1.2353 - val_accuracy: 0.4850 - val_loss: 1.1200
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.5431 - loss: 1.0862 - val_accuracy: 0.5387 - val_loss: 1.0061
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.5853 - loss: 0.9767 - val_accuracy: 0.5487 - val_loss: 0.8968
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.5986 - loss: 0.8946 - val_accuracy: 0.6363 - val_loss: 0.8310
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.6209 - loss: 0.8335 - val_accuracy: 0.6612 - val_loss: 0.7760
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.6339 - loss: 0.7962 - val_accuracy: 0.6775 - val_loss: 0.7406
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.6533 - loss: 0.7525 - val_accuracy: 0.6737 - val_loss: 0.7143
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.6651 - loss: 0.7307 - val_accuracy: 0.6913 - val_loss: 0.6914
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.6748 - loss: 0.7072 - val_accuracy: 0.7088 - val_loss: 0.6674

# %%
net_LCT = ImaNet(name='Bayesian_opt_ARC')

# %%
net_LCT.update_scores(score);

# %%
i = 2
all_scores = {
    'loss': [],
    'val_loss': [],
    'accuracy': [],
    'val_accuracy': []
}

i = 2
while i < 10:

    print(i)

    file_sim = ImaFile(simulations_folder=path_sim + 'AS/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')
    gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

    gene_sim.filter_freq(0.01)
    gene_sim.sort('rows_freq')
    gene_sim.resize((198, 192))
    gene_sim.convert(flip=True)

    gene_sim.subset(get_index_random(gene_sim))
    gene_sim.targets = to_binary(gene_sim.targets)

    score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)

    # Append scores to all_scores dictionary
    all_scores['loss'].extend(score.history['loss'])
    all_scores['val_loss'].extend(score.history['val_loss'])
    all_scores['accuracy'].extend(score.history['accuracy'])
    all_scores['val_accuracy'].extend(score.history['val_accuracy'])

    i += 1
# Out:
# 2
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.6855 - loss: 0.7055 - val_accuracy: 0.6825 - val_loss: 0.6824
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.6912 - loss: 0.6796 - val_accuracy: 0.6938 - val_loss: 0.6667
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7031 - loss: 0.6664 - val_accuracy: 0.6837 - val_loss: 0.6540
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7118 - loss: 0.6574 - val_accuracy: 0.6737 - val_loss: 0.6629
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7126 - loss: 0.6424 - val_accuracy: 0.6737 - val_loss: 0.6603
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7180 - loss: 0.6429 - val_accuracy: 0.6975 - val_loss: 0.6293
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.7325 - loss: 0.6270 - val_accuracy: 0.6837 - val_loss: 0.6432
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7317 - loss: 0.6188 - val_accuracy: 0.6950 - val_loss: 0.6359
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7333 - loss: 0.6112 - val_accuracy: 0.7125 - val_loss: 0.6158
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7455 - loss: 0.5974 - val_accuracy: 0.7125 - val_loss: 0.6202
# 3
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.7105 - loss: 0.6514 - val_accuracy: 0.7250 - val_loss: 0.6124
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7182 - loss: 0.6329 - val_accuracy: 0.7575 - val_loss: 0.6102
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7198 - loss: 0.6266 - val_accuracy: 0.7588 - val_loss: 0.6001
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7424 - loss: 0.6129 - val_accuracy: 0.7525 - val_loss: 0.5957
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7491 - loss: 0.6028 - val_accuracy: 0.7538 - val_loss: 0.5870
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.7618 - loss: 0.5865 - val_accuracy: 0.7563 - val_loss: 0.5791
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7800 - loss: 0.5734 - val_accuracy: 0.7538 - val_loss: 0.5806
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7916 - loss: 0.5623 - val_accuracy: 0.7650 - val_loss: 0.5715
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7982 - loss: 0.5445 - val_accuracy: 0.7675 - val_loss: 0.5601
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8078 - loss: 0.5279 - val_accuracy: 0.7750 - val_loss: 0.5550
# 4
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.7905 - loss: 0.5400 - val_accuracy: 0.8150 - val_loss: 0.5175
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8037 - loss: 0.5170 - val_accuracy: 0.8150 - val_loss: 0.5128
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8241 - loss: 0.4964 - val_accuracy: 0.8250 - val_loss: 0.5133
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8291 - loss: 0.4846 - val_accuracy: 0.8213 - val_loss: 0.5125
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8407 - loss: 0.4725 - val_accuracy: 0.8263 - val_loss: 0.5056
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.8477 - loss: 0.4582 - val_accuracy: 0.8263 - val_loss: 0.4956
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8552 - loss: 0.4467 - val_accuracy: 0.8238 - val_loss: 0.4990
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8580 - loss: 0.4397 - val_accuracy: 0.8263 - val_loss: 0.4977
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8666 - loss: 0.4263 - val_accuracy: 0.8250 - val_loss: 0.4975
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8777 - loss: 0.4213 - val_accuracy: 0.8225 - val_loss: 0.4977
# 5
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.8138 - loss: 0.5144 - val_accuracy: 0.8512 - val_loss: 0.4696
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8243 - loss: 0.4982 - val_accuracy: 0.8587 - val_loss: 0.4686
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8335 - loss: 0.4834 - val_accuracy: 0.8512 - val_loss: 0.4628
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8400 - loss: 0.4806 - val_accuracy: 0.8450 - val_loss: 0.4664
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8465 - loss: 0.4644 - val_accuracy: 0.8425 - val_loss: 0.4639
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8516 - loss: 0.4596 - val_accuracy: 0.8487 - val_loss: 0.4558
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8574 - loss: 0.4480 - val_accuracy: 0.8450 - val_loss: 0.4551
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8612 - loss: 0.4421 - val_accuracy: 0.8438 - val_loss: 0.4559
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8714 - loss: 0.4304 - val_accuracy: 0.8438 - val_loss: 0.4488
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8728 - loss: 0.4242 - val_accuracy: 0.8438 - val_loss: 0.4498
# 6
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.8350 - loss: 0.4813 - val_accuracy: 0.8425 - val_loss: 0.4675
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8427 - loss: 0.4704 - val_accuracy: 0.8500 - val_loss: 0.4666
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8487 - loss: 0.4618 - val_accuracy: 0.8487 - val_loss: 0.4599
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8533 - loss: 0.4479 - val_accuracy: 0.8487 - val_loss: 0.4463
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8610 - loss: 0.4349 - val_accuracy: 0.8487 - val_loss: 0.4504
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8669 - loss: 0.4292 - val_accuracy: 0.8487 - val_loss: 0.4609
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8673 - loss: 0.4260 - val_accuracy: 0.8525 - val_loss: 0.4454
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8752 - loss: 0.4125 - val_accuracy: 0.8550 - val_loss: 0.4410
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8783 - loss: 0.4039 - val_accuracy: 0.8537 - val_loss: 0.4508
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8866 - loss: 0.3999 - val_accuracy: 0.8575 - val_loss: 0.4423
# 7
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.8569 - loss: 0.4424 - val_accuracy: 0.8625 - val_loss: 0.4677
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8836 - loss: 0.4094 - val_accuracy: 0.8650 - val_loss: 0.4614
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8879 - loss: 0.3923 - val_accuracy: 0.8637 - val_loss: 0.4678
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8923 - loss: 0.3820 - val_accuracy: 0.8662 - val_loss: 0.4622
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8892 - loss: 0.3769 - val_accuracy: 0.8637 - val_loss: 0.4699
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8931 - loss: 0.3633 - val_accuracy: 0.8562 - val_loss: 0.4767
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8993 - loss: 0.3578 - val_accuracy: 0.8625 - val_loss: 0.4703
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8982 - loss: 0.3501 - val_accuracy: 0.8625 - val_loss: 0.4670
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9047 - loss: 0.3438 - val_accuracy: 0.8550 - val_loss: 0.4763
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9113 - loss: 0.3333 - val_accuracy: 0.8562 - val_loss: 0.4744
# 8
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.8582 - loss: 0.4306 - val_accuracy: 0.8650 - val_loss: 0.4075
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.8796 - loss: 0.4021 - val_accuracy: 0.8587 - val_loss: 0.4148
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8853 - loss: 0.3900 - val_accuracy: 0.8612 - val_loss: 0.4148
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8951 - loss: 0.3754 - val_accuracy: 0.8637 - val_loss: 0.4083
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8993 - loss: 0.3654 - val_accuracy: 0.8650 - val_loss: 0.4067
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9051 - loss: 0.3547 - val_accuracy: 0.8687 - val_loss: 0.4078
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9115 - loss: 0.3467 - val_accuracy: 0.8725 - val_loss: 0.4073
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9123 - loss: 0.3395 - val_accuracy: 0.8712 - val_loss: 0.4137
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9153 - loss: 0.3297 - val_accuracy: 0.8725 - val_loss: 0.4095
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9220 - loss: 0.3199 - val_accuracy: 0.8700 - val_loss: 0.4152
# 9
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.8712 - loss: 0.4187 - val_accuracy: 0.8913 - val_loss: 0.3734
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8878 - loss: 0.3830 - val_accuracy: 0.8913 - val_loss: 0.3739
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8891 - loss: 0.3664 - val_accuracy: 0.8950 - val_loss: 0.3747
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.8926 - loss: 0.3572 - val_accuracy: 0.8950 - val_loss: 0.3737
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.8993 - loss: 0.3430 - val_accuracy: 0.8975 - val_loss: 0.3745
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9037 - loss: 0.3320 - val_accuracy: 0.8950 - val_loss: 0.3772
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9132 - loss: 0.3254 - val_accuracy: 0.8938 - val_loss: 0.3774
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9181 - loss: 0.3156 - val_accuracy: 0.8963 - val_loss: 0.3814
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9234 - loss: 0.3108 - val_accuracy: 0.8913 - val_loss: 0.3820
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9189 - loss: 0.3039 - val_accuracy: 0.8938 - val_loss: 0.3865

# %% [markdown]
# Better Plotting visualisation

# %%
# Define the number of epochs for plotting
epochs = range(1, len(all_scores['loss']) + 1)

# Function to smooth the data for better visualization (optional)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Create a figure for plotting with better visualization settings
plt.figure(figsize=(14, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, smooth_curve(all_scores['loss']), 'bo-', label='Training Loss')
plt.plot(epochs, smooth_curve(all_scores['val_loss']), 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, smooth_curve(all_scores['accuracy']), 'bo-', label='Training Accuracy')
plt.plot(epochs, smooth_curve(all_scores['val_accuracy']), 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluate the training on the testing dataset, Which is the last batch of the the 10th simulation in the file
# The log the testing validation and loss alongside the F1,

# %%
# Set the simulation index
i = 10

# Create an ImaFile object for the specified simulation folder and model
file_sim = ImaFile(simulations_folder=path_sim + 'AS/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')

# Read the simulation data with the specified parameter and maximum number of replicates
gene_sim_test = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

# Filter the simulations based on a frequency threshold of 0.01
gene_sim_test.filter_freq(0.01)

# Sort the simulations by row frequency
gene_sim_test.sort('rows_freq')

# Resize the simulation data to the specified dimensions (198, 192)
gene_sim_test.resize((198, 192))

# Convert the simulation data with data augmentation (flip=True)
gene_sim_test.convert(flip=True)

# Get a random subset of indices and subset the simulation data
rnd_idx = get_index_random(gene_sim_test)  # no need to create this extra variable
gene_sim_test.subset(rnd_idx)

# Convert the targets to binary format
gene_sim_test.targets = to_binary(gene_sim_test.targets)

# %%
net_LCT.test = model.evaluate(gene_sim_test.data, gene_sim_test.targets, batch_size=None, verbose=0)
print(net_LCT.test) # it will report [loss, accuracy]
# Out:
# [0.40167805552482605, 0.8842499852180481]

# %%
# Make predictions on the validation data
predictions = model.predict(gene_sim_test.data)

# Calculate F1 score
f1 = f1_score(gene_sim_test.targets, predictions.round())

# Calculate precision, recall, and F-score
precision, recall, fscore, _ = precision_recall_fscore_support(gene_sim_test.targets, predictions.round(), average='binary')

# Recall is equivalent to sensitivity
sensitivity = recall

# Compute ROC curve and AUC (Area Under the Curve)
fpr, tpr, _ = roc_curve(gene_sim_test.targets, predictions)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Print additional metrics
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall (Sensitivity): {sensitivity}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# F1 Score: 0.8807622971928922
# Precision: 0.9081253319171535
# Recall (Sensitivity): 0.855

# %%
# Make predictions on the test data using the trained model and store the results in net_LCT
net_LCT.predict(gene_sim_test, model)

# Plot the confusion matrix of the predictions against the true classes, with text labels for clarity
net_LCT.plot_cm(gene_sim_test.classes, text=True)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 0

# %%
path = './'
filename = 'AS_Bayes_opt.keras'

# Save the trained model to a file using the recommended Keras format
model.save(path + filename)
#Model saved to Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the path and filename
path = '/content/drive/My Drive/models/'
filename = 'AS_Bayes_opt.keras'

# Save the trained model to the specified path
model.save(path + filename)
# Out:
# Mounted at /content/drive
