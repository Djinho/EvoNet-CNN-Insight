# %% [markdown]
# ### Data Analysis Pipeline
#
# - **Create Simulation**: Represent Ancient and strong selection.
# - **Leverage Pre-trained Model**: Use the hyperpamaters from bayesian optimisation
# - **Training Regimen**:
#   - Train for 10 epochs.
#   - 10 epochs each from batches 1-9 of training data.
#   - Test on the final batch of unseen data.
# - **40k Simulations used**

# %%
# !git clone https://github.com/Djinho/EvoNet-CNN-Insight.git

# Navigate to the cloned repository
# %cd EvoNet-CNN-Insight/model_training/Ancient_strong
# Out:
# Cloning into 'EvoNet-CNN-Insight'...
# remote: Enumerating objects: 6197, done.
# remote: Counting objects: 100% (1818/1818), done.
# remote: Compressing objects: 100% (1099/1099), done.
# remote: Total 6197 (delta 803), reused 1673 (delta 701), pack-reused 4379 (from 1)
# Receiving objects: 100% (6197/6197), 8.08 GiB | 17.26 MiB/s, done.
# Resolving deltas: 100% (2401/2401), done.
# Updating files: 100% (231/231), done.
# /content/EvoNet-CNN-Insight/model_training/Ancient_strong

# %%
import os
import gzip
import _pickle as pickle

import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models, layers, activations, optimizers, regularizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix

import itertools
import matplotlib.pyplot as plt
import skimage.transform
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense,Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")


# Set a fixed random seed for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Run ImaGene.py

# %%
# %run -i ../../ImaGene.py

# %%
#run to make simulations
import subprocess
subprocess.call("bash ../../generate_dataset.sh params_ancient_strong.txt".split());

# %% [markdown]
#  the first iteration of training.

# %%
path_sim = './'

# %%
file_sim = ImaFile(simulations_folder=path_sim + 'AS/Simulations1', nr_samples=198, model_name='Marth-3epoch-CEU');

# %% [markdown]
# Then, we populate an _ImaGene_ object by specifying the variable we want to estimate/predict (`selection_coeff_hetero`) and how many data points per class we wish to retain.
# As a quick example, we will use only 2000 data points per class.

# %%
gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000);

# %% [markdown]
# We can have a look at the data stored in this object.

# %%
gene_sim.summary();
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 186, max 508, mean 327.057250, std 41.736866

# %%
# Filter simulations based on frequency threshold of 0.01
gene_sim.filter_freq(0.01)

# Sort simulations by row frequency
gene_sim.sort('rows_freq')

# Provide summary of the simulation data
gene_sim.summary()
# Resize simulation data to (198, 192)
gene_sim.resize((198, 192))

# Provide summary of the simulation data
gene_sim.summary()
# Convert simulation data with data augmentation (flip)
gene_sim.convert(flip=True)

# Provide summary of the simulation data
gene_sim.summary()
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 111, max 397, mean 239.376750, std 39.731415
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# 0

# %% [markdown]
# information on the corresponding targets (in this case the selection coefficient, either 0 or selection coefficient of choice in $2N_e$ units with $N_e = 10000$).

# %%
for sel in gene_sim.classes:
    print(sel)
    gene_sim.plot(np.where(gene_sim.targets == sel)[0][0])
# Out:
# 0
# 300

# %%
# Subset the simulation data with random indices
gene_sim.subset(get_index_random(gene_sim))

# Convert targets to binary format
gene_sim.targets = to_binary(gene_sim.targets)

# %% [markdown]
# Use Hyperparameters from the Bayesian Optimisation script

# %%
def build_best_model(input_shape):
    # Best hyperparameters from the new Optuna optimization
    num_layers = 4  # Number of layers
    filters = [44, 83, 72, 64]  # Filters for each convolutional layer
    kernel_size = 3  # Kernel size
    l1 = 0.00013537781122606584  # L1 regularization
    l2 = 0.0037394012860948295  # L2 regularization
    dense_units = 167  # Units in the dense layer
    dropout_rate = 0.18690845934507774  # Dropout rate
    learning_rate = 1.0525370626878665e-05  # Learning rate

    # Building the model based on the provided hyperparameters
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))  # Define the input layer
    for i in range(num_layers):
        model.add(layers.Conv2D(filters=filters[i], kernel_size=(kernel_size, kernel_size), strides=(1, 1), activation='relu',
                                kernel_regularizer=regularizers.l1_l2(l1=l1, l2=l2), padding='same'))  # 'same' padding to preserve dimensions
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Flatten())  # Flatten the output for the Dense layers
    model.add(layers.Dense(units=dense_units, activation='relu'))  # Dense layer
    model.add(layers.Dropout(rate=dropout_rate))  # Dropout layer
    model.add(layers.Dense(units=1, activation='sigmoid'))  # Output layer with sigmoid activation

    optimizer = optimizers.Adam(learning_rate=learning_rate)  # Define optimizer
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])  # Compile the model

    return model

# Assuming gene_sim.data is already preprocessed
input_shape = gene_sim.data.shape[1:]

# Build the model
model = build_best_model(input_shape)

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 192, 44)        │             440 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 99, 96, 44)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 99, 96, 83)          │          32,951 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 49, 48, 83)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 49, 48, 72)          │          53,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 72)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 64)          │          41,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 167)                 │       1,539,239 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 167)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             168 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,668,190 (6.36 MB)
#  Trainable params: 1,668,190 (6.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 146ms/step - accuracy: 0.5079 - loss: 2.0514 - val_accuracy: 0.5312 - val_loss: 2.0350
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5240 - loss: 2.0299 - val_accuracy: 0.5775 - val_loss: 2.0147
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5377 - loss: 2.0090 - val_accuracy: 0.5800 - val_loss: 1.9945
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5195 - loss: 1.9899 - val_accuracy: 0.5900 - val_loss: 1.9745
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5275 - loss: 1.9703 - val_accuracy: 0.5938 - val_loss: 1.9550
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5539 - loss: 1.9492 - val_accuracy: 0.6187 - val_loss: 1.9355
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5619 - loss: 1.9291 - val_accuracy: 0.5738 - val_loss: 1.9169
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5644 - loss: 1.9119 - val_accuracy: 0.5600 - val_loss: 1.8984
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5723 - loss: 1.8929 - val_accuracy: 0.5650 - val_loss: 1.8798
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.5976 - loss: 1.8733 - val_accuracy: 0.5638 - val_loss: 1.8622

# %%
net_LCT = ImaNet(name='Bayesian_opt_ARC')

# %%
net_LCT.update_scores(score);

# %%
i = 2
all_scores = {
    'loss': [],
    'val_loss': [],
    'accuracy': [],
    'val_accuracy': []
}

i = 2
while i < 10:

    print(i)

    file_sim = ImaFile(simulations_folder=path_sim + 'AS/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')
    gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

    gene_sim.filter_freq(0.01)
    gene_sim.sort('rows_freq')
    gene_sim.resize((198, 192))
    gene_sim.convert(flip=True)

    gene_sim.subset(get_index_random(gene_sim))
    gene_sim.targets = to_binary(gene_sim.targets)

    score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)

    # Append scores to all_scores dictionary
    all_scores['loss'].extend(score.history['loss'])
    all_scores['val_loss'].extend(score.history['val_loss'])
    all_scores['accuracy'].extend(score.history['accuracy'])
    all_scores['val_accuracy'].extend(score.history['val_accuracy'])

    i += 1
# Out:
# 2
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.5927 - loss: 1.8566 - val_accuracy: 0.6075 - val_loss: 1.8427
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5927 - loss: 1.8370 - val_accuracy: 0.6175 - val_loss: 1.8225
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.6073 - loss: 1.8170 - val_accuracy: 0.6200 - val_loss: 1.8040
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6070 - loss: 1.7999 - val_accuracy: 0.6150 - val_loss: 1.7864
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.6130 - loss: 1.7817 - val_accuracy: 0.6200 - val_loss: 1.7697
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6126 - loss: 1.7657 - val_accuracy: 0.6125 - val_loss: 1.7531
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6237 - loss: 1.7492 - val_accuracy: 0.6200 - val_loss: 1.7368
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6334 - loss: 1.7324 - val_accuracy: 0.6237 - val_loss: 1.7209
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6379 - loss: 1.7164 - val_accuracy: 0.6250 - val_loss: 1.7055
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6411 - loss: 1.7017 - val_accuracy: 0.6413 - val_loss: 1.6899
# 3
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6124 - loss: 1.7003 - val_accuracy: 0.5987 - val_loss: 1.6886
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6123 - loss: 1.6897 - val_accuracy: 0.6225 - val_loss: 1.6706
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6332 - loss: 1.6726 - val_accuracy: 0.6338 - val_loss: 1.6555
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6344 - loss: 1.6578 - val_accuracy: 0.6562 - val_loss: 1.6375
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6417 - loss: 1.6441 - val_accuracy: 0.6625 - val_loss: 1.6227
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6490 - loss: 1.6301 - val_accuracy: 0.6737 - val_loss: 1.6089
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6564 - loss: 1.6176 - val_accuracy: 0.6862 - val_loss: 1.5937
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6543 - loss: 1.6065 - val_accuracy: 0.6812 - val_loss: 1.5812
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6644 - loss: 1.5939 - val_accuracy: 0.6925 - val_loss: 1.5698
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6707 - loss: 1.5806 - val_accuracy: 0.6963 - val_loss: 1.5577
# 4
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.6830 - loss: 1.5607 - val_accuracy: 0.6975 - val_loss: 1.5340
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6975 - loss: 1.5449 - val_accuracy: 0.7025 - val_loss: 1.5214
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6995 - loss: 1.5339 - val_accuracy: 0.7063 - val_loss: 1.5128
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7026 - loss: 1.5251 - val_accuracy: 0.7075 - val_loss: 1.5026
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6995 - loss: 1.5163 - val_accuracy: 0.7088 - val_loss: 1.4942
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7108 - loss: 1.5078 - val_accuracy: 0.7138 - val_loss: 1.4855
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6977 - loss: 1.4998 - val_accuracy: 0.7088 - val_loss: 1.4786
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6970 - loss: 1.4923 - val_accuracy: 0.7088 - val_loss: 1.4715
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7100 - loss: 1.4840 - val_accuracy: 0.7175 - val_loss: 1.4642
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7130 - loss: 1.4774 - val_accuracy: 0.7100 - val_loss: 1.4581
# 5
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6849 - loss: 1.4902 - val_accuracy: 0.6875 - val_loss: 1.4784
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6935 - loss: 1.4814 - val_accuracy: 0.6900 - val_loss: 1.4715
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6875 - loss: 1.4741 - val_accuracy: 0.6850 - val_loss: 1.4705
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6914 - loss: 1.4712 - val_accuracy: 0.6800 - val_loss: 1.4658
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6897 - loss: 1.4646 - val_accuracy: 0.6800 - val_loss: 1.4600
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6953 - loss: 1.4588 - val_accuracy: 0.6800 - val_loss: 1.4559
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6906 - loss: 1.4562 - val_accuracy: 0.6800 - val_loss: 1.4487
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6993 - loss: 1.4482 - val_accuracy: 0.6850 - val_loss: 1.4436
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6992 - loss: 1.4418 - val_accuracy: 0.6775 - val_loss: 1.4398
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6936 - loss: 1.4366 - val_accuracy: 0.6850 - val_loss: 1.4337
# 6
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6814 - loss: 1.4416 - val_accuracy: 0.6875 - val_loss: 1.4471
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6818 - loss: 1.4403 - val_accuracy: 0.6913 - val_loss: 1.4429
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6758 - loss: 1.4362 - val_accuracy: 0.6888 - val_loss: 1.4371
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6867 - loss: 1.4315 - val_accuracy: 0.6888 - val_loss: 1.4320
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6846 - loss: 1.4257 - val_accuracy: 0.6862 - val_loss: 1.4259
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6855 - loss: 1.4199 - val_accuracy: 0.6925 - val_loss: 1.4222
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6825 - loss: 1.4168 - val_accuracy: 0.6888 - val_loss: 1.4175
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6844 - loss: 1.4093 - val_accuracy: 0.6850 - val_loss: 1.4130
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6910 - loss: 1.4053 - val_accuracy: 0.6862 - val_loss: 1.4092
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6887 - loss: 1.3998 - val_accuracy: 0.6888 - val_loss: 1.4055
# 7
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6873 - loss: 1.4000 - val_accuracy: 0.6500 - val_loss: 1.4376
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6860 - loss: 1.3957 - val_accuracy: 0.6550 - val_loss: 1.4261
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6802 - loss: 1.3913 - val_accuracy: 0.6513 - val_loss: 1.4263
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6851 - loss: 1.3862 - val_accuracy: 0.6575 - val_loss: 1.4187
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6836 - loss: 1.3802 - val_accuracy: 0.6562 - val_loss: 1.4129
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6873 - loss: 1.3784 - val_accuracy: 0.6550 - val_loss: 1.4124
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6878 - loss: 1.3742 - val_accuracy: 0.6550 - val_loss: 1.4089
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6893 - loss: 1.3713 - val_accuracy: 0.6550 - val_loss: 1.4018
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6856 - loss: 1.3642 - val_accuracy: 0.6550 - val_loss: 1.4011
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6891 - loss: 1.3603 - val_accuracy: 0.6550 - val_loss: 1.3978
# 8
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6850 - loss: 1.3657 - val_accuracy: 0.6938 - val_loss: 1.3546
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6850 - loss: 1.3635 - val_accuracy: 0.6925 - val_loss: 1.3507
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6994 - loss: 1.3587 - val_accuracy: 0.6913 - val_loss: 1.3475
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6913 - loss: 1.3593 - val_accuracy: 0.6913 - val_loss: 1.3443
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6881 - loss: 1.3535 - val_accuracy: 0.6913 - val_loss: 1.3414
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6950 - loss: 1.3481 - val_accuracy: 0.6950 - val_loss: 1.3381
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6983 - loss: 1.3444 - val_accuracy: 0.6925 - val_loss: 1.3355
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6972 - loss: 1.3431 - val_accuracy: 0.6938 - val_loss: 1.3330
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6954 - loss: 1.3389 - val_accuracy: 0.6963 - val_loss: 1.3294
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6971 - loss: 1.3361 - val_accuracy: 0.6925 - val_loss: 1.3277
# 9
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.7061 - loss: 1.3302 - val_accuracy: 0.7287 - val_loss: 1.2985
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7070 - loss: 1.3262 - val_accuracy: 0.7262 - val_loss: 1.2953
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6994 - loss: 1.3212 - val_accuracy: 0.7237 - val_loss: 1.2924
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7055 - loss: 1.3217 - val_accuracy: 0.7312 - val_loss: 1.2897
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7017 - loss: 1.3167 - val_accuracy: 0.7300 - val_loss: 1.2871
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7007 - loss: 1.3135 - val_accuracy: 0.7300 - val_loss: 1.2844
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7001 - loss: 1.3103 - val_accuracy: 0.7337 - val_loss: 1.2817
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7058 - loss: 1.3070 - val_accuracy: 0.7325 - val_loss: 1.2792
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7092 - loss: 1.3014 - val_accuracy: 0.7325 - val_loss: 1.2767
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7139 - loss: 1.2998 - val_accuracy: 0.7337 - val_loss: 1.2741

# %% [markdown]
# Better Plotting visualisation

# %%
# Define the number of epochs for plotting
epochs = range(1, len(all_scores['loss']) + 1)

# Function to smooth the data for better visualization (optional)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Create a figure for plotting with better visualization settings
plt.figure(figsize=(14, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, smooth_curve(all_scores['loss']), 'bo-', label='Training Loss')
plt.plot(epochs, smooth_curve(all_scores['val_loss']), 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, smooth_curve(all_scores['accuracy']), 'bo-', label='Training Accuracy')
plt.plot(epochs, smooth_curve(all_scores['val_accuracy']), 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluate the training on the testing dataset, Which is the last batch of the the 10th simulation in the file
# The log the testing validation and loss alongside the F1,

# %%
# Set the simulation index
i = 10

# Create an ImaFile object for the specified simulation folder and model
file_sim = ImaFile(simulations_folder=path_sim + 'AS/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')

# Read the simulation data with the specified parameter and maximum number of replicates
gene_sim_test = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

# Filter the simulations based on a frequency threshold of 0.01
gene_sim_test.filter_freq(0.01)

# Sort the simulations by row frequency
gene_sim_test.sort('rows_freq')

# Resize the simulation data to the specified dimensions (198, 192)
gene_sim_test.resize((198, 192))

# Convert the simulation data with data augmentation (flip=True)
gene_sim_test.convert(flip=True)

# Get a random subset of indices and subset the simulation data
rnd_idx = get_index_random(gene_sim_test)  # no need to create this extra variable
gene_sim_test.subset(rnd_idx)

# Convert the targets to binary format
gene_sim_test.targets = to_binary(gene_sim_test.targets)

# %%
net_LCT.test = model.evaluate(gene_sim_test.data, gene_sim_test.targets, batch_size=None, verbose=0)
print(net_LCT.test) # it will report [loss, accuracy]
# Out:
# [1.2872629165649414, 0.7152500152587891]

# %%
# Make predictions on the validation data
predictions = model.predict(gene_sim_test.data)

# Calculate F1 score
f1 = f1_score(gene_sim_test.targets, predictions.round())

# Calculate precision, recall, and F-score
precision, recall, fscore, _ = precision_recall_fscore_support(gene_sim_test.targets, predictions.round(), average='binary')

# Recall is equivalent to sensitivity
sensitivity = recall

# Compute ROC curve and AUC (Area Under the Curve)
fpr, tpr, _ = roc_curve(gene_sim_test.targets, predictions)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Print additional metrics
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall (Sensitivity): {sensitivity}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# F1 Score: 0.6968325791855204
# Precision: 0.7450199203187251
# Recall (Sensitivity): 0.6545

# %%
# Make predictions on the test data using the trained model and store the results in net_LCT
net_LCT.predict(gene_sim_test, model)

# Plot the confusion matrix of the predictions against the true classes, with text labels for clarity
net_LCT.plot_cm(gene_sim_test.classes, text=True)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 0

# %%
path = './'
filename = 'AS_Bayes_opt.keras'

# Save the trained model to a file using the recommended Keras format
model.save(path + filename)
#Model saved to Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the path and filename
path = '/content/drive/My Drive/models/'
filename = 'AS_Bayes_opt.keras'

# Save the trained model to the specified path
model.save(path + filename)
