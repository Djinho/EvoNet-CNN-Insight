# %% [markdown]
# ### Data Analysis Pipeline
#
# - **Create Simulation**: Represent Recent and moderate selection.
# - **Leverage Pre-trained Model**: Use Baseline Imagene CNN architecture
# - **Training Regimen**:
#   - Train for 10 epochs.
#   - 10 epochs each from batches 1-9 of training data.
#   - Test on the final batch of unseen data.
# - **40k Simulations used**

# %%
# !git clone https://github.com/Djinho/EvoNet-CNN-Insight.git

# Navigate to the cloned repository
# %cd EvoNet-CNN-Insight/model_training/recent_moderate
# Out:
# Cloning into 'EvoNet-CNN-Insight'...
# remote: Enumerating objects: 5837, done.
# remote: Counting objects: 100% (1458/1458), done.
# remote: Compressing objects: 100% (975/975), done.
# remote: Total 5837 (delta 582), reused 1304 (delta 466), pack-reused 4379
# Receiving objects: 100% (5837/5837), 8.07 GiB | 17.53 MiB/s, done.
# Resolving deltas: 100% (2180/2180), done.
# Updating files: 100% (226/226), done.
# /content/EvoNet-CNN-Insight/model_training/recent_moderate

# %%
import os
import gzip
import _pickle as pickle

import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models, layers, activations, optimizers, regularizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix

import itertools
import matplotlib.pyplot as plt
import skimage.transform
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense,Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")


# Set a fixed random seed for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Run ImaGene.py

# %%
# %run -i ../../ImaGene.py

# %%
#run to make simulations
import subprocess
subprocess.call("bash ../../generate_dataset.sh params_recent_moderate.txt".split());

# %% [markdown]
#  the first iteration of training.

# %%
path_sim = './'

# %%
file_sim = ImaFile(simulations_folder=path_sim + 'RM/Simulations1', nr_samples=198, model_name='Marth-3epoch-CEU');

# %% [markdown]
# Then, we populate an _ImaGene_ object by specifying the variable we want to estimate/predict (`selection_coeff_hetero`) and how many data points per class we wish to retain.
# As a quick example, we will use only 2000 data points per class.

# %%
gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000);

# %% [markdown]
# We can have a look at the data stored in this object.

# %%
gene_sim.summary();
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 203, max 493, mean 341.473250, std 35.400597

# %%
# Filter simulations based on frequency threshold of 0.01
gene_sim.filter_freq(0.01)

# Sort simulations by row frequency
gene_sim.sort('rows_freq')

# Provide summary of the simulation data
gene_sim.summary()
# Resize simulation data to (198, 192)
gene_sim.resize((198, 192))

# Provide summary of the simulation data
gene_sim.summary()
# Convert simulation data with data augmentation (flip)
gene_sim.convert(flip=True)

# Provide summary of the simulation data
gene_sim.summary()
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 117, max 398, mean 254.190500, std 33.206162
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# 0

# %% [markdown]
# information on the corresponding targets (in this case the selection coefficient, either 0 or selection coefficient of choice in $2N_e$ units with $N_e = 10000$).

# %%
for sel in gene_sim.classes:
    print(sel)
    gene_sim.plot(np.where(gene_sim.targets == sel)[0][0])
# Out:
# 0
# 200

# %%
# Subset the simulation data with random indices
gene_sim.subset(get_index_random(gene_sim))

# Convert targets to binary format
gene_sim.targets = to_binary(gene_sim.targets)

# %% [markdown]
# Transfer Learning with VGG16 model
# > Applied the data augmentation

# %%
model = models.Sequential([
                    layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.005, l2=0.005), padding='valid', input_shape=gene_sim.data.shape[1:]),
                    layers.MaxPooling2D(pool_size=(2,2)),
                    layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.005, l2=0.005), padding='valid'),
                    layers.MaxPooling2D(pool_size=(2,2)),
                    layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.005, l2=0.005), padding='valid'),
                    layers.MaxPooling2D(pool_size=(2,2)),
                    layers.Flatten(),
                    layers.Dense(units=128, activation='relu'),
                    layers.Dense(units=1, activation='sigmoid')])
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])


# Print the summary of the model to see its architecture
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 196, 190, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 98, 95, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 96, 93, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 48, 46, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 46, 44, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 23, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32384)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       4,145,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,173,473 (15.92 MB)
#  Trainable params: 4,173,473 (15.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 89ms/step - accuracy: 0.5290 - loss: 5.9596 - val_accuracy: 0.6338 - val_loss: 2.6539
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5795 - loss: 2.0887 - val_accuracy: 0.6313 - val_loss: 1.0417
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5384 - loss: 0.9393 - val_accuracy: 0.5175 - val_loss: 0.7893
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4945 - loss: 0.7790 - val_accuracy: 0.4825 - val_loss: 0.7644
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5086 - loss: 0.7635 - val_accuracy: 0.4825 - val_loss: 0.7633
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5086 - loss: 0.7628 - val_accuracy: 0.4825 - val_loss: 0.7633
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5086 - loss: 0.7628 - val_accuracy: 0.4825 - val_loss: 0.7633
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5086 - loss: 0.7628 - val_accuracy: 0.4825 - val_loss: 0.7633
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5086 - loss: 0.7628 - val_accuracy: 0.4825 - val_loss: 0.7633
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5086 - loss: 0.7628 - val_accuracy: 0.4825 - val_loss: 0.7633

# %%
net_LCT = ImaNet(name='Imagene_Baseline_ARC')

# %%
net_LCT.update_scores(score);

# %%
i = 2
all_scores = {
    'loss': [],
    'val_loss': [],
    'accuracy': [],
    'val_accuracy': []
}

i = 2
while i < 10:

    print(i)

    file_sim = ImaFile(simulations_folder=path_sim + 'RM/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')
    gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

    gene_sim.filter_freq(0.01)
    gene_sim.sort('rows_freq')
    gene_sim.resize((198, 192))
    gene_sim.convert(flip=True)

    gene_sim.subset(get_index_random(gene_sim))
    gene_sim.targets = to_binary(gene_sim.targets)

    score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)

    # Append scores to all_scores dictionary
    all_scores['loss'].extend(score.history['loss'])
    all_scores['val_loss'].extend(score.history['val_loss'])
    all_scores['accuracy'].extend(score.history['accuracy'])
    all_scores['val_accuracy'].extend(score.history['val_accuracy'])

    i += 1
# Out:
# 2
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7633
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7632
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7632
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7631
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7631
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7631
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7631
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7631
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7631
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5095 - loss: 0.7628 - val_accuracy: 0.4800 - val_loss: 0.7631
# 3
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.4925 - loss: 0.7629 - val_accuracy: 0.4725 - val_loss: 0.7630
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5070 - loss: 0.7629 - val_accuracy: 0.4725 - val_loss: 0.7631
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7632
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7633
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7634
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7634
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7635
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7635
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7635
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5070 - loss: 0.7628 - val_accuracy: 0.4725 - val_loss: 0.7635
# 4
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.4958 - loss: 0.7630 - val_accuracy: 0.5063 - val_loss: 0.7628
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4958 - loss: 0.7630 - val_accuracy: 0.5063 - val_loss: 0.7628
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4958 - loss: 0.7630 - val_accuracy: 0.5063 - val_loss: 0.7628
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4958 - loss: 0.7629 - val_accuracy: 0.5063 - val_loss: 0.7629
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4958 - loss: 0.7629 - val_accuracy: 0.5063 - val_loss: 0.7629
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4956 - loss: 0.7629 - val_accuracy: 0.5063 - val_loss: 0.7629
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4870 - loss: 0.7629 - val_accuracy: 0.5063 - val_loss: 0.7629
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4878 - loss: 0.7629 - val_accuracy: 0.4938 - val_loss: 0.7629
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5067 - loss: 0.7629 - val_accuracy: 0.4938 - val_loss: 0.7629
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5054 - loss: 0.7629 - val_accuracy: 0.4938 - val_loss: 0.7629
# 5
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5078 - loss: 0.7629 - val_accuracy: 0.4913 - val_loss: 0.7629
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5078 - loss: 0.7629 - val_accuracy: 0.4913 - val_loss: 0.7629
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5078 - loss: 0.7629 - val_accuracy: 0.4913 - val_loss: 0.7630
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5078 - loss: 0.7629 - val_accuracy: 0.4913 - val_loss: 0.7630
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5078 - loss: 0.7629 - val_accuracy: 0.4913 - val_loss: 0.7630
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5078 - loss: 0.7628 - val_accuracy: 0.4913 - val_loss: 0.7630
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5078 - loss: 0.7628 - val_accuracy: 0.4913 - val_loss: 0.7630
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5078 - loss: 0.7628 - val_accuracy: 0.4913 - val_loss: 0.7630
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5078 - loss: 0.7628 - val_accuracy: 0.4913 - val_loss: 0.7630
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5078 - loss: 0.7628 - val_accuracy: 0.4913 - val_loss: 0.7630
# 6
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5080 - loss: 0.7628 - val_accuracy: 0.5050 - val_loss: 0.7629
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5080 - loss: 0.7629 - val_accuracy: 0.5050 - val_loss: 0.7629
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5080 - loss: 0.7629 - val_accuracy: 0.5050 - val_loss: 0.7629
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5080 - loss: 0.7629 - val_accuracy: 0.4950 - val_loss: 0.7629
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4808 - loss: 0.7629 - val_accuracy: 0.4950 - val_loss: 0.7629
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4905 - loss: 0.7629 - val_accuracy: 0.4950 - val_loss: 0.7629
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4921 - loss: 0.7629 - val_accuracy: 0.4950 - val_loss: 0.7629
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4886 - loss: 0.7629 - val_accuracy: 0.4950 - val_loss: 0.7629
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4907 - loss: 0.7630 - val_accuracy: 0.4950 - val_loss: 0.7629
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4907 - loss: 0.7630 - val_accuracy: 0.4950 - val_loss: 0.7629
# 7
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.4983 - loss: 0.7629 - val_accuracy: 0.4663 - val_loss: 0.7629
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4879 - loss: 0.7629 - val_accuracy: 0.4663 - val_loss: 0.7631
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5014 - loss: 0.7629 - val_accuracy: 0.4663 - val_loss: 0.7634
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5014 - loss: 0.7629 - val_accuracy: 0.4663 - val_loss: 0.7635
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5014 - loss: 0.7629 - val_accuracy: 0.4663 - val_loss: 0.7637
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5014 - loss: 0.7629 - val_accuracy: 0.4663 - val_loss: 0.7638
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5014 - loss: 0.7629 - val_accuracy: 0.4663 - val_loss: 0.7640
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5014 - loss: 0.7630 - val_accuracy: 0.4663 - val_loss: 0.7641
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5014 - loss: 0.7630 - val_accuracy: 0.4663 - val_loss: 0.7642
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5014 - loss: 0.7630 - val_accuracy: 0.4663 - val_loss: 0.7642
# 8
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7637
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7637
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7636
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7636
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7635
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7635
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7635
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5091 - loss: 0.7627 - val_accuracy: 0.4787 - val_loss: 0.7635
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5091 - loss: 0.7628 - val_accuracy: 0.4787 - val_loss: 0.7635
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5091 - loss: 0.7628 - val_accuracy: 0.4787 - val_loss: 0.7635
# 9
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5066 - loss: 0.7628 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5066 - loss: 0.7628 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5066 - loss: 0.7628 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5066 - loss: 0.7629 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5066 - loss: 0.7629 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5066 - loss: 0.7629 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5066 - loss: 0.7629 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5025 - loss: 0.7629 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5020 - loss: 0.7629 - val_accuracy: 0.5025 - val_loss: 0.7629
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4999 - loss: 0.7629 - val_accuracy: 0.4975 - val_loss: 0.7629

# %% [markdown]
# Better Plotting visualisation

# %%
# Define the number of epochs for plotting
epochs = range(1, len(all_scores['loss']) + 1)

# Function to smooth the data for better visualization (optional)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Create a figure for plotting with better visualization settings
plt.figure(figsize=(14, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, smooth_curve(all_scores['loss']), 'bo-', label='Training Loss')
plt.plot(epochs, smooth_curve(all_scores['val_loss']), 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, smooth_curve(all_scores['accuracy']), 'bo-', label='Training Accuracy')
plt.plot(epochs, smooth_curve(all_scores['val_accuracy']), 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluate the training on the testing dataset, Which is the last batch of the the 10th simulation in the file
# The log the testing validation and loss alongside the F1,

# %%
# Set the simulation index
i = 10

# Create an ImaFile object for the specified simulation folder and model
file_sim = ImaFile(simulations_folder=path_sim + 'RM/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')

# Read the simulation data with the specified parameter and maximum number of replicates
gene_sim_test = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

# Filter the simulations based on a frequency threshold of 0.01
gene_sim_test.filter_freq(0.01)

# Sort the simulations by row frequency
gene_sim_test.sort('rows_freq')

# Resize the simulation data to the specified dimensions (198, 192)
gene_sim_test.resize((198, 192))

# Convert the simulation data with data augmentation (flip=True)
gene_sim_test.convert(flip=True)

# Get a random subset of indices and subset the simulation data
rnd_idx = get_index_random(gene_sim_test)  # no need to create this extra variable
gene_sim_test.subset(rnd_idx)

# Convert the targets to binary format
gene_sim_test.targets = to_binary(gene_sim_test.targets)

# %%
net_LCT.test = model.evaluate(gene_sim_test.data, gene_sim_test.targets, batch_size=None, verbose=0)
print(net_LCT.test) # it will report [loss, accuracy]
# Out:
# [0.7628830075263977, 0.5]

# %%
# Make predictions on the validation data
predictions = model.predict(gene_sim_test.data)

# Calculate F1 score
f1 = f1_score(gene_sim_test.targets, predictions.round())

# Calculate precision, recall, and F-score
precision, recall, fscore, _ = precision_recall_fscore_support(gene_sim_test.targets, predictions.round(), average='binary')

# Recall is equivalent to sensitivity
sensitivity = recall

# Compute ROC curve and AUC (Area Under the Curve)
fpr, tpr, _ = roc_curve(gene_sim_test.targets, predictions)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Print additional metrics
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall (Sensitivity): {sensitivity}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# F1 Score: 0.0
# Precision: 0.0
# Recall (Sensitivity): 0.0

# %%
# Make predictions on the test data using the trained model and store the results in net_LCT
net_LCT.predict(gene_sim_test, model)

# Plot the confusion matrix of the predictions against the true classes, with text labels for clarity
net_LCT.plot_cm(gene_sim_test.classes, text=True)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0
