# %% [markdown]
# ### Data Analysis Pipeline
#
# - **Create Simulation**: Represent Intermediate and storng selection.
# - **Leverage Pre-trained Model**: Use the hyperpamaters from bayesian optimisation
# - **Training Regimen**:
#   - Train for 10 epochs.
#   - 10 epochs each from batches 1-9 of training data.
#   - Test on the final batch of unseen data.
# - **40k Simulations used**

# %%
# !git clone https://github.com/Djinho/EvoNet-CNN-Insight.git

# Navigate to the cloned repository
# %cd EvoNet-CNN-Insight/model_training/intermediate_strong
# Out:
# Cloning into 'EvoNet-CNN-Insight'...
# remote: Enumerating objects: 5954, done.
# remote: Counting objects: 100% (1575/1575), done.
# remote: Compressing objects: 100% (1092/1092), done.
# remote: Total 5954 (delta 662), reused 1304 (delta 466), pack-reused 4379
# Receiving objects: 100% (5954/5954), 8.07 GiB | 16.72 MiB/s, done.
# Resolving deltas: 100% (2260/2260), done.
# Updating files: 100% (230/230), done.
# /content/EvoNet-CNN-Insight/model_training/intermediate_strong

# %%
import os
import gzip
import _pickle as pickle

import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models, layers, activations, optimizers, regularizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix

import itertools
import matplotlib.pyplot as plt
import skimage.transform
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense,Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")


# Set a fixed random seed for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Run ImaGene.py

# %%
# %run -i ../../ImaGene.py

# %% [markdown]
#  the first iteration of training.

# %%
path_sim = './'

# %%
file_sim = ImaFile(simulations_folder=path_sim + 'IS/Simulations1', nr_samples=198, model_name='Marth-3epoch-CEU');

# %% [markdown]
# Then, we populate an _ImaGene_ object by specifying the variable we want to estimate/predict (`selection_coeff_hetero`) and how many data points per class we wish to retain.
# As a quick example, we will use only 2000 data points per class.

# %%
gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000);

# %% [markdown]
# We can have a look at the data stored in this object.

# %%
gene_sim.summary();
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 194, max 465, mean 321.679000, std 43.821986

# %%
# Filter simulations based on frequency threshold of 0.01
gene_sim.filter_freq(0.01)

# Sort simulations by row frequency
gene_sim.sort('rows_freq')

# Provide summary of the simulation data
gene_sim.summary()
# Resize simulation data to (198, 192)
gene_sim.resize((198, 192))

# Provide summary of the simulation data
gene_sim.summary()
# Convert simulation data with data augmentation (flip)
gene_sim.convert(flip=True)

# Provide summary of the simulation data
gene_sim.summary()
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 113, max 363, mean 237.002000, std 40.109400
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# 0

# %% [markdown]
# information on the corresponding targets (in this case the selection coefficient, either 0 or selection coefficient of choice in $2N_e$ units with $N_e = 10000$).

# %%
for sel in gene_sim.classes:
    print(sel)
    gene_sim.plot(np.where(gene_sim.targets == sel)[0][0])
# Out:
# 0
# 300

# %%
# Subset the simulation data with random indices
gene_sim.subset(get_index_random(gene_sim))

# Convert targets to binary format
gene_sim.targets = to_binary(gene_sim.targets)

# %% [markdown]
# Use Hyperparameters from the Bayesian Optimisation script

# %%
def build_best_model(input_shape):
    # Best hyperparameters from Optuna optimization
    num_layers = 4
    filters = [124, 107, 37, 107]
    kernel_size = 3
    l1 = 0.00023342282213110015
    l2 = 6.698426243226582e-06
    dense_units = 205
    dropout_rate = 0.3223287518244954
    learning_rate = 0.00011551960587189376

    # Building the model based on the best hyperparameters
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))  # Define the input layer
    for i in range(num_layers):
        model.add(layers.Conv2D(filters=filters[i], kernel_size=(kernel_size, kernel_size), strides=(1, 1), activation='relu',
                                kernel_regularizer=regularizers.l1_l2(l1=l1, l2=l2), padding='same'))  # Use 'same' padding to avoid dimension issues
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Flatten())  # Flatten the output for the Dense layers
    model.add(layers.Dense(units=dense_units, activation='relu'))  # Add Dense layer
    model.add(layers.Dropout(rate=dropout_rate))  # Add Dropout layer
    model.add(layers.Dense(units=1, activation='sigmoid'))  # Output layer with sigmoid activation

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Define optimizer
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])  # Compile the model

    return model

#gene_sim.data is already preprocessed
input_shape = gene_sim.data.shape[1:]

# Build the model
model = build_best_model(input_shape)

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 192, 124)       │           1,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 99, 96, 124)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 99, 96, 107)         │         119,519 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 49, 48, 107)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 49, 48, 37)          │          35,668 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 37)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 107)         │          35,738 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 107)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 15408)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 205)                 │       3,158,845 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 205)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             206 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,351,216 (12.78 MB)
#  Trainable params: 3,351,216 (12.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 28s 241ms/step - accuracy: 0.5054 - loss: 1.9717 - val_accuracy: 0.5612 - val_loss: 1.8219
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.5800 - loss: 1.7709 - val_accuracy: 0.6875 - val_loss: 1.5875
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.6482 - loss: 1.5822 - val_accuracy: 0.6950 - val_loss: 1.4474
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.6917 - loss: 1.4429 - val_accuracy: 0.7350 - val_loss: 1.3311
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.7023 - loss: 1.3449 - val_accuracy: 0.7250 - val_loss: 1.2518
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7046 - loss: 1.2651 - val_accuracy: 0.7375 - val_loss: 1.1896
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7345 - loss: 1.1904 - val_accuracy: 0.7300 - val_loss: 1.1318
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7280 - loss: 1.1378 - val_accuracy: 0.7387 - val_loss: 1.0907
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7350 - loss: 1.0923 - val_accuracy: 0.7337 - val_loss: 1.0548
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7403 - loss: 1.0591 - val_accuracy: 0.7312 - val_loss: 1.0313

# %%
net_LCT = ImaNet(name='Bayesian_opt_ARC')

# %%
net_LCT.update_scores(score);

# %%
i = 2
all_scores = {
    'loss': [],
    'val_loss': [],
    'accuracy': [],
    'val_accuracy': []
}

i = 2
while i < 10:

    print(i)

    file_sim = ImaFile(simulations_folder=path_sim + 'IS/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')
    gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

    gene_sim.filter_freq(0.01)
    gene_sim.sort('rows_freq')
    gene_sim.resize((198, 192))
    gene_sim.convert(flip=True)

    gene_sim.subset(get_index_random(gene_sim))
    gene_sim.targets = to_binary(gene_sim.targets)

    score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)

    # Append scores to all_scores dictionary
    all_scores['loss'].extend(score.history['loss'])
    all_scores['val_loss'].extend(score.history['val_loss'])
    all_scores['accuracy'].extend(score.history['accuracy'])
    all_scores['val_accuracy'].extend(score.history['val_accuracy'])

    i += 1
# Out:
# 2
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.7333 - loss: 1.0279 - val_accuracy: 0.7038 - val_loss: 1.0467
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7311 - loss: 1.0106 - val_accuracy: 0.6800 - val_loss: 1.0551
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7240 - loss: 1.0073 - val_accuracy: 0.6762 - val_loss: 1.0557
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.7269 - loss: 0.9987 - val_accuracy: 0.7038 - val_loss: 1.0110
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.7343 - loss: 0.9778 - val_accuracy: 0.7100 - val_loss: 1.0034
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7407 - loss: 0.9658 - val_accuracy: 0.7125 - val_loss: 0.9980
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7419 - loss: 0.9567 - val_accuracy: 0.7113 - val_loss: 0.9910
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7434 - loss: 0.9489 - val_accuracy: 0.7125 - val_loss: 0.9736
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7427 - loss: 0.9347 - val_accuracy: 0.7163 - val_loss: 0.9724
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7479 - loss: 0.9291 - val_accuracy: 0.7150 - val_loss: 0.9656
# 3
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.7246 - loss: 0.9567 - val_accuracy: 0.7513 - val_loss: 0.9030
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7263 - loss: 0.9412 - val_accuracy: 0.7525 - val_loss: 0.8888
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7311 - loss: 0.9265 - val_accuracy: 0.7500 - val_loss: 0.8830
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7346 - loss: 0.9156 - val_accuracy: 0.7550 - val_loss: 0.8722
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7458 - loss: 0.9053 - val_accuracy: 0.7538 - val_loss: 0.8651
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7362 - loss: 0.8996 - val_accuracy: 0.7613 - val_loss: 0.8567
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7345 - loss: 0.8911 - val_accuracy: 0.7575 - val_loss: 0.8500
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7426 - loss: 0.8820 - val_accuracy: 0.7575 - val_loss: 0.8443
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7440 - loss: 0.8751 - val_accuracy: 0.7563 - val_loss: 0.8397
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7489 - loss: 0.8692 - val_accuracy: 0.7563 - val_loss: 0.8339
# 4
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7573 - loss: 0.8754 - val_accuracy: 0.7075 - val_loss: 0.9085
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7460 - loss: 0.8701 - val_accuracy: 0.7300 - val_loss: 0.8776
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7460 - loss: 0.8568 - val_accuracy: 0.7325 - val_loss: 0.8595
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7615 - loss: 0.8491 - val_accuracy: 0.7325 - val_loss: 0.8558
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7580 - loss: 0.8453 - val_accuracy: 0.7337 - val_loss: 0.8519
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7533 - loss: 0.8386 - val_accuracy: 0.7400 - val_loss: 0.8398
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7629 - loss: 0.8287 - val_accuracy: 0.7375 - val_loss: 0.8400
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7564 - loss: 0.8280 - val_accuracy: 0.7350 - val_loss: 0.8419
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7556 - loss: 0.8227 - val_accuracy: 0.7387 - val_loss: 0.8287
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7631 - loss: 0.8133 - val_accuracy: 0.7425 - val_loss: 0.8256
# 5
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7540 - loss: 0.8247 - val_accuracy: 0.7500 - val_loss: 0.8450
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.7495 - loss: 0.8252 - val_accuracy: 0.7450 - val_loss: 0.8455
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7547 - loss: 0.8226 - val_accuracy: 0.7500 - val_loss: 0.8373
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7583 - loss: 0.8108 - val_accuracy: 0.7500 - val_loss: 0.8318
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7600 - loss: 0.8072 - val_accuracy: 0.7500 - val_loss: 0.8256
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7636 - loss: 0.8002 - val_accuracy: 0.7487 - val_loss: 0.8247
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7637 - loss: 0.7943 - val_accuracy: 0.7450 - val_loss: 0.8122
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7642 - loss: 0.7875 - val_accuracy: 0.7450 - val_loss: 0.8084
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7691 - loss: 0.7849 - val_accuracy: 0.7475 - val_loss: 0.8130
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7693 - loss: 0.7788 - val_accuracy: 0.7450 - val_loss: 0.8002
# 6
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.7396 - loss: 0.8259 - val_accuracy: 0.7200 - val_loss: 0.8299
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7319 - loss: 0.8126 - val_accuracy: 0.7362 - val_loss: 0.8190
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7461 - loss: 0.8078 - val_accuracy: 0.7375 - val_loss: 0.8156
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7426 - loss: 0.8026 - val_accuracy: 0.7275 - val_loss: 0.8142
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7545 - loss: 0.7913 - val_accuracy: 0.7337 - val_loss: 0.8111
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7467 - loss: 0.7902 - val_accuracy: 0.7312 - val_loss: 0.8079
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7514 - loss: 0.7859 - val_accuracy: 0.7325 - val_loss: 0.8047
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7532 - loss: 0.7793 - val_accuracy: 0.7337 - val_loss: 0.8019
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7481 - loss: 0.7753 - val_accuracy: 0.7325 - val_loss: 0.7994
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7509 - loss: 0.7687 - val_accuracy: 0.7337 - val_loss: 0.7963
# 7
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.7508 - loss: 0.7745 - val_accuracy: 0.7312 - val_loss: 0.8084
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7474 - loss: 0.7621 - val_accuracy: 0.7225 - val_loss: 0.8349
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7427 - loss: 0.7675 - val_accuracy: 0.7237 - val_loss: 0.8210
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7430 - loss: 0.7569 - val_accuracy: 0.7200 - val_loss: 0.8275
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7451 - loss: 0.7567 - val_accuracy: 0.7212 - val_loss: 0.8225
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7457 - loss: 0.7501 - val_accuracy: 0.7212 - val_loss: 0.8213
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7470 - loss: 0.7487 - val_accuracy: 0.7212 - val_loss: 0.8174
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7545 - loss: 0.7420 - val_accuracy: 0.7237 - val_loss: 0.8121
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7574 - loss: 0.7391 - val_accuracy: 0.7275 - val_loss: 0.8108
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7591 - loss: 0.7310 - val_accuracy: 0.7250 - val_loss: 0.8113
# 8
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.7558 - loss: 0.7345 - val_accuracy: 0.7513 - val_loss: 0.7486
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7672 - loss: 0.7318 - val_accuracy: 0.7450 - val_loss: 0.7502
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7671 - loss: 0.7217 - val_accuracy: 0.7425 - val_loss: 0.7469
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7739 - loss: 0.7196 - val_accuracy: 0.7450 - val_loss: 0.7447
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7722 - loss: 0.7142 - val_accuracy: 0.7400 - val_loss: 0.7445
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7795 - loss: 0.7095 - val_accuracy: 0.7425 - val_loss: 0.7403
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7767 - loss: 0.7061 - val_accuracy: 0.7513 - val_loss: 0.7321
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7877 - loss: 0.6950 - val_accuracy: 0.7500 - val_loss: 0.7289
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7864 - loss: 0.6898 - val_accuracy: 0.7487 - val_loss: 0.7213
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7926 - loss: 0.6876 - val_accuracy: 0.7500 - val_loss: 0.7199
# 9
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.7412 - loss: 0.7532 - val_accuracy: 0.7563 - val_loss: 0.7067
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.7562 - loss: 0.7405 - val_accuracy: 0.7650 - val_loss: 0.7057
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.7580 - loss: 0.7307 - val_accuracy: 0.7625 - val_loss: 0.6979
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7633 - loss: 0.7247 - val_accuracy: 0.7638 - val_loss: 0.6927
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7644 - loss: 0.7177 - val_accuracy: 0.7650 - val_loss: 0.6880
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7686 - loss: 0.7151 - val_accuracy: 0.7713 - val_loss: 0.6837
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7728 - loss: 0.7013 - val_accuracy: 0.7713 - val_loss: 0.6780
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7799 - loss: 0.6946 - val_accuracy: 0.7775 - val_loss: 0.6729
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7761 - loss: 0.6883 - val_accuracy: 0.7775 - val_loss: 0.6666
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7847 - loss: 0.6764 - val_accuracy: 0.7875 - val_loss: 0.6605

# %% [markdown]
# Better Plotting visualisation

# %%
# Define the number of epochs for plotting
epochs = range(1, len(all_scores['loss']) + 1)

# Function to smooth the data for better visualization (optional)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Create a figure for plotting with better visualization settings
plt.figure(figsize=(14, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, smooth_curve(all_scores['loss']), 'bo-', label='Training Loss')
plt.plot(epochs, smooth_curve(all_scores['val_loss']), 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, smooth_curve(all_scores['accuracy']), 'bo-', label='Training Accuracy')
plt.plot(epochs, smooth_curve(all_scores['val_accuracy']), 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluate the training on the testing dataset, Which is the last batch of the the 10th simulation in the file
# The log the testing validation and loss alongside the F1,

# %%
# Set the simulation index
i = 10

# Create an ImaFile object for the specified simulation folder and model
file_sim = ImaFile(simulations_folder=path_sim + 'IS/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')

# Read the simulation data with the specified parameter and maximum number of replicates
gene_sim_test = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

# Filter the simulations based on a frequency threshold of 0.01
gene_sim_test.filter_freq(0.01)

# Sort the simulations by row frequency
gene_sim_test.sort('rows_freq')

# Resize the simulation data to the specified dimensions (198, 192)
gene_sim_test.resize((198, 192))

# Convert the simulation data with data augmentation (flip=True)
gene_sim_test.convert(flip=True)

# Get a random subset of indices and subset the simulation data
rnd_idx = get_index_random(gene_sim_test)  # no need to create this extra variable
gene_sim_test.subset(rnd_idx)

# Convert the targets to binary format
gene_sim_test.targets = to_binary(gene_sim_test.targets)

# %%
net_LCT.test = model.evaluate(gene_sim_test.data, gene_sim_test.targets, batch_size=None, verbose=0)
print(net_LCT.test) # it will report [loss, accuracy]
# Out:
# [0.6515050530433655, 0.7957500219345093]

# %%
# Make predictions on the validation data
predictions = model.predict(gene_sim_test.data)

# Calculate F1 score
f1 = f1_score(gene_sim_test.targets, predictions.round())

# Calculate precision, recall, and F-score
precision, recall, fscore, _ = precision_recall_fscore_support(gene_sim_test.targets, predictions.round(), average='binary')

# Recall is equivalent to sensitivity
sensitivity = recall

# Compute ROC curve and AUC (Area Under the Curve)
fpr, tpr, _ = roc_curve(gene_sim_test.targets, predictions)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Print additional metrics
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall (Sensitivity): {sensitivity}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step
# F1 Score: 0.7972201538843385
# Precision: 0.7915229176934451
# Recall (Sensitivity): 0.803

# %%
# Make predictions on the test data using the trained model and store the results in net_LCT
net_LCT.predict(gene_sim_test, model)

# Plot the confusion matrix of the predictions against the true classes, with text labels for clarity
net_LCT.plot_cm(gene_sim_test.classes, text=True)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step
# 0

# %%
path = './'
filename = 'IS_Bayes_opt.keras'

# Save the trained model to a file using the recommended Keras format
model.save(path + filename)
#Model saved to Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the path and filename
path = '/content/drive/My Drive/models/'
filename = 'IS_Bayes_opt.keras'

# Save the trained model to the specified path
model.save(path + filename)
# Out:
# Mounted at /content/drive
