# %% [markdown]
# ### Data Analysis Pipeline
#
# - **Create Simulation**: Represent Ancient and weak selection.
# - **Leverage Pre-trained Model**: Use the hyperpamaters from bayesian optimisation
# - **Training Regimen**:
#   - Train for 10 epochs.
#   - 10 epochs each from batches 1-9 of training data.
#   - Test on the final batch of unseen data.
# - **40k Simulations used**

# %%
# !git clone https://github.com/Djinho/EvoNet-CNN-Insight.git

# Navigate to the cloned repository
# %cd EvoNet-CNN-Insight/model_training/Ancient_weak
# Out:
# Cloning into 'EvoNet-CNN-Insight'...
# remote: Enumerating objects: 5915, done.
# remote: Counting objects: 100% (1536/1536), done.
# remote: Compressing objects: 100% (1053/1053), done.
# remote: Total 5915 (delta 634), reused 1304 (delta 466), pack-reused 4379
# Receiving objects: 100% (5915/5915), 8.07 GiB | 17.34 MiB/s, done.
# Resolving deltas: 100% (2225/2225), done.
# Updating files: 100% (230/230), done.
# /content/EvoNet-CNN-Insight/model_training/Ancient_weak

# %%
import os
import gzip
import _pickle as pickle

import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models, layers, activations, optimizers, regularizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix

import itertools
import matplotlib.pyplot as plt
import skimage.transform
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense,Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")


# Set a fixed random seed for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Run ImaGene.py

# %%
# %run -i ../../ImaGene.py

# %%
#run to make simulations
import subprocess
subprocess.call("bash ../../generate_dataset.sh params_ancient_weak.txt".split());

# %% [markdown]
#  the first iteration of training.

# %%
path_sim = './'

# %%
file_sim = ImaFile(simulations_folder=path_sim + 'AW/Simulations1', nr_samples=198, model_name='Marth-3epoch-CEU');

# %% [markdown]
# Then, we populate an _ImaGene_ object by specifying the variable we want to estimate/predict (`selection_coeff_hetero`) and how many data points per class we wish to retain.
# As a quick example, we will use only 2000 data points per class.

# %%
gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000);

# %% [markdown]
# We can have a look at the data stored in this object.

# %%
gene_sim.summary();
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 187, max 460, mean 321.207750, std 49.124175

# %%
# Filter simulations based on frequency threshold of 0.01
gene_sim.filter_freq(0.01)

# Sort simulations by row frequency
gene_sim.sort('rows_freq')

# Provide summary of the simulation data
gene_sim.summary()
# Resize simulation data to (198, 192)
gene_sim.resize((198, 192))

# Provide summary of the simulation data
gene_sim.summary()
# Convert simulation data with data augmentation (flip)
gene_sim.convert(flip=True)

# Provide summary of the simulation data
gene_sim.summary()
# Out:
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 111, max 363, mean 232.786500, std 47.185029
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# An object of 4000 image(s)
# Rows: min 198, max 198, mean 198.000000, std 0.000000
# Columns: min 192, max 192, mean 192.000000, std 0.000000
# 0

# %% [markdown]
# information on the corresponding targets (in this case the selection coefficient, either 0 or selection coefficient of choice in $2N_e$ units with $N_e = 10000$).

# %%
for sel in gene_sim.classes:
    print(sel)
    gene_sim.plot(np.where(gene_sim.targets == sel)[0][0])
# Out:
# 0
# 100

# %%
# Subset the simulation data with random indices
gene_sim.subset(get_index_random(gene_sim))

# Convert targets to binary format
gene_sim.targets = to_binary(gene_sim.targets)

# %% [markdown]
# Use Hyperparameters from the Bayesian Optimisation script

# %%
def build_best_model(input_shape):
    # Best hyperparameters from Optuna optimization
    num_layers = 3
    filters = [79, 79, 125]
    kernel_size = 2
    l1 = 1.4238915610455433e-06
    l2 = 0.0011892049877332892
    dense_units = 227
    dropout_rate = 0.2605345852243278
    learning_rate = 2.5834311151381096e-05

    # Building the model based on the best hyperparameters
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))  # Define the input layer
    for i in range(num_layers):
        model.add(layers.Conv2D(filters=filters[i], kernel_size=(kernel_size, kernel_size), strides=(1, 1), activation='relu',
                                kernel_regularizer=regularizers.l1_l2(l1=l1, l2=l2), padding='same'))  # Use 'same' padding to avoid dimension issues
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Flatten())  # Flatten the output for the Dense layers
    model.add(layers.Dense(units=dense_units, activation='relu'))  # Add Dense layer
    model.add(layers.Dropout(rate=dropout_rate))  # Add Dropout layer
    model.add(layers.Dense(units=1, activation='sigmoid'))  # Output layer with sigmoid activation

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Define optimizer
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])  # Compile the model

    return model

# gene_sim.data is already preprocessed
input_shape = gene_sim.data.shape[1:]

# Build the model
model = build_best_model(input_shape)

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 192, 79)        │             395 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 99, 96, 79)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 99, 96, 79)          │          25,043 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 49, 48, 79)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 49, 48, 125)         │          39,625 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 125)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 72000)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 227)                 │      16,344,227 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 227)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             228 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,409,518 (62.60 MB)
#  Trainable params: 16,409,518 (62.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.5293 - loss: 0.9053 - val_accuracy: 0.6625 - val_loss: 0.8756
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.6182 - loss: 0.8729 - val_accuracy: 0.7000 - val_loss: 0.8331
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.6924 - loss: 0.8311 - val_accuracy: 0.7013 - val_loss: 0.7972
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.6899 - loss: 0.8015 - val_accuracy: 0.7063 - val_loss: 0.7733
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.6932 - loss: 0.7737 - val_accuracy: 0.7100 - val_loss: 0.7520
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7114 - loss: 0.7588 - val_accuracy: 0.7188 - val_loss: 0.7375
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7116 - loss: 0.7394 - val_accuracy: 0.7200 - val_loss: 0.7245
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7269 - loss: 0.7280 - val_accuracy: 0.7337 - val_loss: 0.7143
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7388 - loss: 0.7134 - val_accuracy: 0.7425 - val_loss: 0.7046
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7555 - loss: 0.6936 - val_accuracy: 0.7462 - val_loss: 0.6942

# %%
net_LCT = ImaNet(name='Bayesian_opt_ARC')

# %%
net_LCT.update_scores(score);

# %%
i = 2
all_scores = {
    'loss': [],
    'val_loss': [],
    'accuracy': [],
    'val_accuracy': []
}

i = 2
while i < 10:

    print(i)

    file_sim = ImaFile(simulations_folder=path_sim + 'AW/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')
    gene_sim = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

    gene_sim.filter_freq(0.01)
    gene_sim.sort('rows_freq')
    gene_sim.resize((198, 192))
    gene_sim.convert(flip=True)

    gene_sim.subset(get_index_random(gene_sim))
    gene_sim.targets = to_binary(gene_sim.targets)

    score = model.fit(gene_sim.data, gene_sim.targets, batch_size=64, epochs=10, verbose=1, validation_split=0.20)

    # Append scores to all_scores dictionary
    all_scores['loss'].extend(score.history['loss'])
    all_scores['val_loss'].extend(score.history['val_loss'])
    all_scores['accuracy'].extend(score.history['accuracy'])
    all_scores['val_accuracy'].extend(score.history['val_accuracy'])

    i += 1
# Out:
# 2
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7632 - loss: 0.6844 - val_accuracy: 0.7600 - val_loss: 0.6801
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7603 - loss: 0.6755 - val_accuracy: 0.7775 - val_loss: 0.6714
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7689 - loss: 0.6679 - val_accuracy: 0.7738 - val_loss: 0.6659
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7643 - loss: 0.6584 - val_accuracy: 0.7688 - val_loss: 0.6624
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7754 - loss: 0.6462 - val_accuracy: 0.7950 - val_loss: 0.6480
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7851 - loss: 0.6383 - val_accuracy: 0.7675 - val_loss: 0.6539
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7881 - loss: 0.6354 - val_accuracy: 0.7825 - val_loss: 0.6442
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7884 - loss: 0.6284 - val_accuracy: 0.7825 - val_loss: 0.6420
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7887 - loss: 0.6229 - val_accuracy: 0.7713 - val_loss: 0.6434
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7860 - loss: 0.6202 - val_accuracy: 0.7788 - val_loss: 0.6371
# 3
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.7641 - loss: 0.6493 - val_accuracy: 0.7925 - val_loss: 0.6161
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7620 - loss: 0.6486 - val_accuracy: 0.7987 - val_loss: 0.6106
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7610 - loss: 0.6514 - val_accuracy: 0.7975 - val_loss: 0.6024
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7627 - loss: 0.6448 - val_accuracy: 0.7975 - val_loss: 0.5996
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.7585 - loss: 0.6357 - val_accuracy: 0.7987 - val_loss: 0.5983
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7738 - loss: 0.6305 - val_accuracy: 0.8012 - val_loss: 0.5964
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7707 - loss: 0.6307 - val_accuracy: 0.7937 - val_loss: 0.5955
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7712 - loss: 0.6221 - val_accuracy: 0.7900 - val_loss: 0.5949
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7774 - loss: 0.6201 - val_accuracy: 0.7937 - val_loss: 0.5921
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7716 - loss: 0.6171 - val_accuracy: 0.7925 - val_loss: 0.5910
# 4
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7643 - loss: 0.6316 - val_accuracy: 0.7663 - val_loss: 0.6239
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7800 - loss: 0.6137 - val_accuracy: 0.7700 - val_loss: 0.6211
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7757 - loss: 0.6105 - val_accuracy: 0.7688 - val_loss: 0.6197
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - accuracy: 0.7786 - loss: 0.6102 - val_accuracy: 0.7688 - val_loss: 0.6177
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - accuracy: 0.7861 - loss: 0.6032 - val_accuracy: 0.7688 - val_loss: 0.6171
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7863 - loss: 0.6002 - val_accuracy: 0.7713 - val_loss: 0.6152
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7751 - loss: 0.5944 - val_accuracy: 0.7738 - val_loss: 0.6139
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7830 - loss: 0.5968 - val_accuracy: 0.7738 - val_loss: 0.6132
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7849 - loss: 0.5910 - val_accuracy: 0.7763 - val_loss: 0.6128
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7862 - loss: 0.5863 - val_accuracy: 0.7700 - val_loss: 0.6107
# 5
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7785 - loss: 0.6164 - val_accuracy: 0.7850 - val_loss: 0.5965
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7790 - loss: 0.6088 - val_accuracy: 0.7837 - val_loss: 0.5956
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7839 - loss: 0.6091 - val_accuracy: 0.7825 - val_loss: 0.5951
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7821 - loss: 0.6037 - val_accuracy: 0.7837 - val_loss: 0.5943
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7890 - loss: 0.5978 - val_accuracy: 0.7825 - val_loss: 0.5943
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7882 - loss: 0.5954 - val_accuracy: 0.7837 - val_loss: 0.5934
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7875 - loss: 0.5921 - val_accuracy: 0.7837 - val_loss: 0.5923
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7895 - loss: 0.5892 - val_accuracy: 0.7850 - val_loss: 0.5942
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7890 - loss: 0.5895 - val_accuracy: 0.7850 - val_loss: 0.5915
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7917 - loss: 0.5821 - val_accuracy: 0.7850 - val_loss: 0.5929
# 6
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7964 - loss: 0.5819 - val_accuracy: 0.7837 - val_loss: 0.5866
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7983 - loss: 0.5862 - val_accuracy: 0.7700 - val_loss: 0.5991
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7991 - loss: 0.5849 - val_accuracy: 0.7713 - val_loss: 0.5959
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7983 - loss: 0.5830 - val_accuracy: 0.7725 - val_loss: 0.5973
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - accuracy: 0.7991 - loss: 0.5769 - val_accuracy: 0.7700 - val_loss: 0.5968
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.8011 - loss: 0.5748 - val_accuracy: 0.7713 - val_loss: 0.5923
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.8053 - loss: 0.5710 - val_accuracy: 0.7700 - val_loss: 0.5938
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.8059 - loss: 0.5672 - val_accuracy: 0.7725 - val_loss: 0.5916
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.8084 - loss: 0.5683 - val_accuracy: 0.7688 - val_loss: 0.5939
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.8129 - loss: 0.5636 - val_accuracy: 0.7675 - val_loss: 0.5976
# 7
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7753 - loss: 0.6108 - val_accuracy: 0.7500 - val_loss: 0.6240
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7798 - loss: 0.5965 - val_accuracy: 0.7600 - val_loss: 0.6126
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7843 - loss: 0.5898 - val_accuracy: 0.7625 - val_loss: 0.6102
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7832 - loss: 0.5862 - val_accuracy: 0.7613 - val_loss: 0.6131
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7863 - loss: 0.5850 - val_accuracy: 0.7625 - val_loss: 0.6116
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7899 - loss: 0.5809 - val_accuracy: 0.7625 - val_loss: 0.6106
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7921 - loss: 0.5796 - val_accuracy: 0.7613 - val_loss: 0.6098
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7942 - loss: 0.5730 - val_accuracy: 0.7613 - val_loss: 0.6089
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7933 - loss: 0.5740 - val_accuracy: 0.7650 - val_loss: 0.6066
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7981 - loss: 0.5699 - val_accuracy: 0.7650 - val_loss: 0.6061
# 8
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7893 - loss: 0.5869 - val_accuracy: 0.7638 - val_loss: 0.6053
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7833 - loss: 0.5926 - val_accuracy: 0.7650 - val_loss: 0.6044
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7822 - loss: 0.5880 - val_accuracy: 0.7675 - val_loss: 0.6052
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7851 - loss: 0.5862 - val_accuracy: 0.7663 - val_loss: 0.6044
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7858 - loss: 0.5814 - val_accuracy: 0.7675 - val_loss: 0.6044
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7861 - loss: 0.5823 - val_accuracy: 0.7663 - val_loss: 0.6040
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.7895 - loss: 0.5794 - val_accuracy: 0.7663 - val_loss: 0.6054
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7886 - loss: 0.5780 - val_accuracy: 0.7688 - val_loss: 0.6033
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7918 - loss: 0.5732 - val_accuracy: 0.7688 - val_loss: 0.6038
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7890 - loss: 0.5741 - val_accuracy: 0.7663 - val_loss: 0.6044
# 9
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7754 - loss: 0.6059 - val_accuracy: 0.7975 - val_loss: 0.5840
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7740 - loss: 0.5995 - val_accuracy: 0.8000 - val_loss: 0.5817
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7765 - loss: 0.5938 - val_accuracy: 0.8000 - val_loss: 0.5798
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7751 - loss: 0.5913 - val_accuracy: 0.8025 - val_loss: 0.5830
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7799 - loss: 0.5910 - val_accuracy: 0.7987 - val_loss: 0.5816
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7822 - loss: 0.5870 - val_accuracy: 0.8050 - val_loss: 0.5806
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7833 - loss: 0.5851 - val_accuracy: 0.8062 - val_loss: 0.5805
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7854 - loss: 0.5796 - val_accuracy: 0.8062 - val_loss: 0.5805
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7884 - loss: 0.5810 - val_accuracy: 0.8050 - val_loss: 0.5786
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7861 - loss: 0.5738 - val_accuracy: 0.8025 - val_loss: 0.5771

# %% [markdown]
# Better Plotting visualisation

# %%
# Define the number of epochs for plotting
epochs = range(1, len(all_scores['loss']) + 1)

# Function to smooth the data for better visualization (optional)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Create a figure for plotting with better visualization settings
plt.figure(figsize=(14, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, smooth_curve(all_scores['loss']), 'bo-', label='Training Loss')
plt.plot(epochs, smooth_curve(all_scores['val_loss']), 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, smooth_curve(all_scores['accuracy']), 'bo-', label='Training Accuracy')
plt.plot(epochs, smooth_curve(all_scores['val_accuracy']), 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluate the training on the testing dataset, Which is the last batch of the the 10th simulation in the file
# The log the testing validation and loss alongside the F1,

# %%
# Set the simulation index
i = 10

# Create an ImaFile object for the specified simulation folder and model
file_sim = ImaFile(simulations_folder=path_sim + 'AW/Simulations' + str(i), nr_samples=198, model_name='Marth-3epoch-CEU')

# Read the simulation data with the specified parameter and maximum number of replicates
gene_sim_test = file_sim.read_simulations(parameter_name='selection_coeff_hetero', max_nrepl=4000)

# Filter the simulations based on a frequency threshold of 0.01
gene_sim_test.filter_freq(0.01)

# Sort the simulations by row frequency
gene_sim_test.sort('rows_freq')

# Resize the simulation data to the specified dimensions (198, 192)
gene_sim_test.resize((198, 192))

# Convert the simulation data with data augmentation (flip=True)
gene_sim_test.convert(flip=True)

# Get a random subset of indices and subset the simulation data
rnd_idx = get_index_random(gene_sim_test)  # no need to create this extra variable
gene_sim_test.subset(rnd_idx)

# Convert the targets to binary format
gene_sim_test.targets = to_binary(gene_sim_test.targets)

# %%
net_LCT.test = model.evaluate(gene_sim_test.data, gene_sim_test.targets, batch_size=None, verbose=0)
print(net_LCT.test) # it will report [loss, accuracy]
# Out:
# [0.5935525298118591, 0.7760000228881836]

# %%
# Make predictions on the validation data
predictions = model.predict(gene_sim_test.data)

# Calculate F1 score
f1 = f1_score(gene_sim_test.targets, predictions.round())

# Calculate precision, recall, and F-score
precision, recall, fscore, _ = precision_recall_fscore_support(gene_sim_test.targets, predictions.round(), average='binary')

# Recall is equivalent to sensitivity
sensitivity = recall

# Compute ROC curve and AUC (Area Under the Curve)
fpr, tpr, _ = roc_curve(gene_sim_test.targets, predictions)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Print additional metrics
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall (Sensitivity): {sensitivity}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# F1 Score: 0.755858310626703
# Precision: 0.8305389221556886
# Recall (Sensitivity): 0.6935

# %%
# Make predictions on the test data using the trained model and store the results in net_LCT
net_LCT.predict(gene_sim_test, model)

# Plot the confusion matrix of the predictions against the true classes, with text labels for clarity
net_LCT.plot_cm(gene_sim_test.classes, text=True)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 0

# %%
path = './'
filename = 'AW_Bayes_opt.keras'

# Save the trained model to a file using the recommended Keras format
model.save(path + filename)
#Model saved to Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the path and filename
path = '/content/drive/My Drive/models/'
filename = 'AW_Bayes_opt.keras'

# Save the trained model to the specified path
model.save(path + filename)
# Out:
# Mounted at /content/drive
