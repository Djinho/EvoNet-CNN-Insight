# %% [markdown]
# <a href="https://colab.research.google.com/github/Djinho/EvoNet-CNN-Insight/blob/main/Plots_For_Genes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data with abbreviations and full names
models = [
    'AS',  # Ancient & Strong
    'AM',  # Ancient & Moderate
    'AW',  # Ancient & Weak
    'IS',  # Intermediate & Strong
    'IM',  # Intermediate & Moderate
    'IW',  # Intermediate & Weak
    'RS',  # Recent & Strong
    'RM'   # Recent & Moderate
]

full_names = [
    'Ancient & Strong',
    'Ancient & Moderate',
    'Ancient & Weak',
    'Intermediate & Strong',
    'Intermediate & Moderate',
    'Intermediate & Weak',
    'Recent & Strong',
    'Recent & Moderate'
]

posterior_probabilities = [
    0.9999975,
    0.9962553,
    0.99997115,
    0.9437715,
    0.9999083,
    0.9998765,
    0.9234599,
    0.6096408
]

# Color highlighting for highest and lowest values
colors = ['#4c72b0'] * len(models)  # A more neutral blue color for all bars
max_index = np.argmax(posterior_probabilities)
min_index = np.argmin(posterior_probabilities)
colors[max_index] = '#55a868'  # Green for the highest value
colors[min_index] = '#c44e52'  # Red for the lowest value

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(models, posterior_probabilities, color=colors)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Posterior Probabilities', fontsize=14)
plt.title('Posterior Probabilities for SLC45A2 (Under Strong Selection)', fontsize=16, weight='bold')
plt.ylim(0, 1.1)  # Adjust y-axis limit for better visibility

# Adding full names inside the bars, vertically
for bar, full_name in zip(bars, full_names):
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2, yval / 2,  # Place in the middle of the bar
        full_name,
        ha='center',
        va='center',
        rotation='vertical',
        fontsize=10,
        color='white',
        weight='bold'
    )
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 6), ha='center', va='bottom', fontsize=10)

# Adding gridlines for a more scientific look
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Enhancing overall style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()  # Adjust layout to prevent label cutoff

# Show the plot
plt.show()

# %% [markdown]
# TYR

# %%
# Data with abbreviations and full names
models = [
    'AS',  # Ancient & Strong
    'AM',  # Ancient & Moderate
    'AW',  # Ancient & Weak
    'IS',  # Intermediate & Strong
    'IM',  # Intermediate & Moderate
    'IW',  # Intermediate & Weak
    'RS',  # Recent & Strong
    'RM'   # Recent & Moderate
]

full_names = [
    'Ancient & Strong',
    'Ancient & Moderate',
    'Ancient & Weak',
    'Intermediate & Strong',
    'Intermediate & Moderate',
    'Intermediate & Weak',
    'Recent & Strong',
    'Recent & Moderate'
]

posterior_probabilities = [
    0.031325493,
    0.4143524,
    0.79495406,
    0.61814266,
    0.9999825,
    0.99938357,
    0.99966025,
    0.997465
]

# Color highlighting for highest and lowest values
colors = ['#4c72b0'] * len(models)  # A more neutral blue color for all bars
max_index = np.argmax(posterior_probabilities)
min_index = np.argmin(posterior_probabilities)
colors[max_index] = '#55a868'  # Green for the highest value
colors[min_index] = '#c44e52'  # Red for the lowest value

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(models, posterior_probabilities, color=colors)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Posterior Probabilities', fontsize=14)
plt.title('Posterior Probabilities for TYR (Under Moderate Selection)', fontsize=16, weight='bold')
plt.ylim(0, 1.1)  # Adjust y-axis limit for better visibility

# Adding full names inside the bars, vertically
for bar, full_name in zip(bars, full_names):
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2, yval / 2,  # Place in the middle of the bar
        full_name,
        ha='center',
        va='center',
        rotation='vertical',
        fontsize=10,
        color='white',
        weight='bold'
    )
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 6), ha='center', va='bottom', fontsize=10)

# Adding gridlines for a more scientific look
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Enhancing overall style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()  # Adjust layout to prevent label cutoff

# Show the plot
plt.show()

# %% [markdown]
# OCA2

# %%
# Data with abbreviations and full names
models = [
    'AS',  # Ancient & Strong
    'AM',  # Ancient & Moderate
    'AW',  # Ancient & Weak
    'IS',  # Intermediate & Strong
    'IM',  # Intermediate & Moderate
    'IW',  # Intermediate & Weak
    'RS',  # Recent & Strong
    'RM'   # Recent & Moderate
]

full_names = [
    'Ancient & Strong',
    'Ancient & Moderate',
    'Ancient & Weak',
    'Intermediate & Strong',
    'Intermediate & Moderate',
    'Intermediate & Weak',
    'Recent & Strong',
    'Recent & Moderate'
]

posterior_probabilities = [
    0.91677576,
    0.8746481,
    0.9988042,
    0.9866002,
    0.99978894,
    0.9969222,
    0.91350234,
    0.9834473
]

# Color highlighting for highest and lowest values
colors = ['#4c72b0'] * len(models)  # A more neutral blue color for all bars
max_index = np.argmax(posterior_probabilities)
min_index = np.argmin(posterior_probabilities)
colors[max_index] = '#55a868'  # Green for the highest value
colors[min_index] = '#c44e52'  # Red for the lowest value

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(models, posterior_probabilities, color=colors)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Posterior Probabilities', fontsize=14)
plt.title('Posterior Probabilities for OCA2 (Under Strong Selection)', fontsize=16, weight='bold')
plt.ylim(0, 1.1)  # Adjust y-axis limit for better visibility

# Adding full names inside the bars, vertically
for bar, full_name in zip(bars, full_names):
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2, yval / 2,  # Place in the middle of the bar
        full_name,
        ha='center',
        va='center',
        rotation='vertical',
        fontsize=10,
        color='white',
        weight='bold'
    )
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 6), ha='center', va='bottom', fontsize=10)

# Adding gridlines for a more scientific look
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Enhancing overall style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()  # Adjust layout to prevent label cutoff

# Show the plot
plt.show()

# %% [markdown]
# KITLG

# %%
# Data with abbreviations and full names
models = [
    'AS',  # Ancient & Strong
    'AM',  # Ancient & Moderate
    'AW',  # Ancient & Weak
    'IS',  # Intermediate & Strong
    'IM',  # Intermediate & Moderate
    'IW',  # Intermediate & Weak
    'RS',  # Recent & Strong
    'RM'   # Recent & Moderate
]

full_names = [
    'Ancient & Strong',
    'Ancient & Moderate',
    'Ancient & Weak',
    'Intermediate & Strong',
    'Intermediate & Moderate',
    'Intermediate & Weak',
    'Recent & Strong',
    'Recent & Moderate'
]

posterior_probabilities = [
    0.9705227,
    0.9340623,
    0.99936634,
    0.41052908,
    0.99999094,
    0.99901533,
    0.99997246,
    0.9919308
]

# Color highlighting for highest and lowest values
colors = ['#4c72b0'] * len(models)  # A more neutral blue color for all bars
max_index = np.argmax(posterior_probabilities)
min_index = np.argmin(posterior_probabilities)
colors[max_index] = '#55a868'  # Green for the highest value
colors[min_index] = '#c44e52'  # Red for the lowest value

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(models, posterior_probabilities, color=colors)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Posterior Probabilities', fontsize=14)
plt.title('Posterior Probabilities for KITLG (Under Weak Selection)', fontsize=16, weight='bold')
plt.ylim(0, 1.1)  # Adjust y-axis limit for better visibility

# Adding full names inside the bars, vertically
for bar, full_name in zip(bars, full_names):
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2, yval / 2,  # Place in the middle of the bar
        full_name,
        ha='center',
        va='center',
        rotation='vertical',
        fontsize=10,
        color='white',
        weight='bold'
    )
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 6), ha='center', va='bottom', fontsize=10)

# Adding gridlines for a more scientific look
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Enhancing overall style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()  # Adjust layout to prevent label cutoff

# Show the plot
plt.show()

# %% [markdown]
# IRF4

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data with abbreviations and full names
models = [
    'AS',  # Ancient & Strong
    'AM',  # Ancient & Moderate
    'AW',  # Ancient & Weak
    'IS',  # Intermediate & Strong
    'IM',  # Intermediate & Moderate
    'IW',  # Intermediate & Weak
    'RS',  # Recent & Strong
    'RM'   # Recent & Moderate
]

full_names = [
    'Ancient & Strong',
    'Ancient & Moderate',
    'Ancient & Weak',
    'Intermediate & Strong',
    'Intermediate & Moderate',
    'Intermediate & Weak',
    'Recent & Strong',
    'Recent & Moderate'
]

posterior_probabilities = [
    0.16579019,
    0.2250365,
    0.37499258,
    0.1745862,
    0.89342886,
    0.007158009,
    0.0008955849,
    0.020208418
]

# Color highlighting for highest and lowest values
colors = ['#4c72b0'] * len(models)  # A more neutral blue color for all bars
max_index = np.argmax(posterior_probabilities)
min_index = np.argmin(posterior_probabilities)
colors[max_index] = '#55a868'  # Green for the highest value
colors[min_index] = '#c44e52'  # Red for the lowest value

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(models, posterior_probabilities, color=colors)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Posterior Probabilities', fontsize=14)
plt.title('Posterior Probabilities for IRF4 (Under Weak Selection)', fontsize=16, weight='bold')
plt.ylim(0, 1.1)  # Adjust y-axis limit for better visibility

# Adding full names inside the bars, vertically
for bar, full_name in zip(bars, full_names):
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2, yval / 2,  # Place in the middle of the bar
        full_name,
        ha='center',
        va='center',
        rotation='vertical',
        fontsize=10,
        color='white',
        weight='bold'
    )
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 8), ha='center', va='bottom', fontsize=10)

# Adding gridlines for a more scientific look
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Enhancing overall style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()  # Adjust layout to prevent label cutoff

# Show the plot
plt.show()

# %% [markdown]
# LCT

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data with abbreviations and full names
models = [
    'AS',  # Ancient & Strong
    'AM',  # Ancient & Moderate
    'AW',  # Ancient & Weak
    'IS',  # Intermediate & Strong
    'IM',  # Intermediate & Moderate
    'IW',  # Intermediate & Weak
    'RS',  # Recent & Strong
    'RM'   # Recent & Moderate
]

full_names = [
    'Ancient & Strong',
    'Ancient & Moderate',
    'Ancient & Weak',
    'Intermediate & Strong',
    'Intermediate & Moderate',
    'Intermediate & Weak',
    'Recent & Strong',
    'Recent & Moderate'
]

posterior_probabilities = [
    0.9946765,
    0.91302806,
    0.9989668,
    0.9834236,
    0.9999503,
    0.999286,
    0.9998142,
    0.90287393
]

# Color highlighting for highest and lowest values
colors = ['#4c72b0'] * len(models)  # A more neutral blue color for all bars
max_index = np.argmax(posterior_probabilities)
min_index = np.argmin(posterior_probabilities)
colors[max_index] = '#55a868'  # Green for the highest value
colors[min_index] = '#c44e52'  # Red for the lowest value

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(models, posterior_probabilities, color=colors)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Posterior Probabilities', fontsize=14)
plt.title('Posterior Probabilities for LCT (Under Strong Selection)', fontsize=16, weight='bold')
plt.ylim(0, 1.1)  # Adjust y-axis limit for better visibility

# Adding full names inside the bars, vertically
for bar, full_name in zip(bars, full_names):
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2, yval / 2,  # Place in the middle of the bar
        full_name,
        ha='center',
        va='center',
        rotation='vertical',
        fontsize=10,
        color='white',
        weight='bold'
    )
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 8), ha='center', va='bottom', fontsize=10)

# Adding gridlines for a more scientific look
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Enhancing overall style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()  # Adjust layout to prevent label cutoff

# Show the plot
plt.show()
